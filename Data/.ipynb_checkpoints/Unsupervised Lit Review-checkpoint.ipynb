# %% [markdown]
# # Graphics for the Paper: A review of unsupervised learning and visual analytics techniques for non-residential building energy analysis
#
# Oct 9, 2015
#
# Clayton Miller

# %%
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string
import math
import bibtexparser
from bibtexparser.bparser import BibTexParser
from bibtexparser.customization import *
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# %matplotlib inline

# %%
sns.set_style('whitegrid')
sns.set_context(context='paper')

# %%
litdata = pd.read_csv("ZoteroExport.csv", index_col=0)

# %%
litdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, I4TWCJAN to QB7SH8HI
# Data columns (total 86 columns):
# Item Type               125 non-null object
# Publication Year        122 non-null float64
# Author                  122 non-null object
# Title                   125 non-null object
# Publication Title       110 non-null object
# ISBN                    24 non-null object
# ISSN                    23 non-null object
# DOI                     76 non-null object
# Url                     110 non-null object
# Abstract Note           61 non-null object
# Date                    122 non-null object
# Date Added              125 non-null object
# Date Modified           125 non-null object
# Access Date             41 non-null object
# Pages                   95 non-null object
# Num Pages               3 non-null float64
# Issue                   38 non-null object
# Volume                  62 non-null object
# Number Of Volumes       2 non-null object
# Journal Abbreviation    57 non-null object
# Short Title             16 non-null object
# Series                  8 non-null object
# Series Number           2 non-null float64
# Series Text             0 non-null float64
# Series Title            1 non-null object
# Publisher               39 non-null object
# Place                   40 non-null object
# Language                6 non-null object
# Rights                  2 non-null object
# Type                    1 non-null object
# Archive                 0 non-null float64
# Archive Location        0 non-null float64
# Library Catalog         48 non-null object
# Call Number             1 non-null object
# Extra                   2 non-null object
# Notes                   0 non-null float64
# File Attachments        123 non-null object
# Link Attachments        0 non-null float64
# Manual Tags             108 non-null object
# Automatic Tags          4 non-null object
# Editor                  3 non-null object
# Series Editor           0 non-null float64
# Translator              0 non-null float64
# Contributor             0 non-null float64
# Attorney Agent          0 non-null float64
# Book Author             0 non-null float64
# Cast Member             0 non-null float64
# Commenter               0 non-null float64
# Composer                0 non-null float64
# Cosponsor               0 non-null float64
# Counsel                 0 non-null float64
# Interviewer             0 non-null float64
# Producer                0 non-null float64
# Recipient               0 non-null float64
# Reviewed Author         0 non-null float64
# Scriptwriter            0 non-null float64
# Words By                0 non-null float64
# Guest                   0 non-null float64
# Number                  0 non-null float64
# Edition                 1 non-null object
# Running Time            0 non-null float64
# Scale                   0 non-null float64
# Medium                  0 non-null float64
# Artwork Size            0 non-null float64
# Filing Date             0 non-null float64
# Application Number      0 non-null float64
# Assignee                0 non-null float64
# Issuing Authority       0 non-null float64
# Country                 0 non-null float64
# Meeting Name            0 non-null float64
# Conference Name         39 non-null object
# Court                   0 non-null float64
# References              0 non-null float64
# Reporter                0 non-null float64
# Legal Status            0 non-null float64
# Priority Numbers        0 non-null float64
# Programming Language    0 non-null float64
# Version                 0 non-null float64
# System                  0 non-null float64
# Code                    0 non-null float64
# Code Number             0 non-null float64
# Section                 0 non-null float64
# Session                 0 non-null float64
# Committee               0 non-null float64
# History                 0 non-null float64
# Legislative Body        0 non-null float64
# dtypes: float64(51), object(35)
# memory usage: 85.0+ KB

# %% [markdown]
# Test Graphic

# %%
fig = plt.figure()
litdata["Item Type"].value_counts().plot(kind='barh', figsize=(3,2))
plt.subplots_adjust(left=0.35, bottom=0.2)
plt.title("Publication Types")
plt.xlabel("Number of Publications")
fig.savefig("PubType.pdf")

# %% [markdown]
# ## Organize Tags

# %%
litdata["Review"] = litdata["Manual Tags"].str.contains("Review")

# %%
SectorTags = ["BuildingEnergyAnalysis", "ElectricalEngineering", "ComputerScience", "BuildingSimulation"]

ApplicationTags_General = ["AnomalyDetection", "Operations", "PortfolioAnalysis", "SmartMeter" ]

ApplicationTags_Specific = ["Component", "Subsystem", "WholeBuilding", 
                            "Controls", "OccupancyDetection", "RetrofitAnalysis", "EnergyManagment",
                            "Characterization", "Classification", "Targeting",
                            "LoadProfiling", "CustomerClassification", "Disaggregation"]

TechniqueTags_General = ["Clustering", "NoveltyDetection", "MotifandDiscordDetection", 
                         "RuleExtraction", "VisualAnalytics"]

TechniqueTags_Specific = ["AntColony", "Bayesian", "ClassificationandRegressionTree", "DataAssociationRules", 
                          "EmpiricalModeDecomposition", "FourierTransform", "GeneralizedAdditiveModels", 
                          "GeneralizedExtremeStudentizedDeviate", "MarkovModel", "Hierarchical",
                          "IncrementalSummarizationandPatternChar", "K-Means", 
                          "LinearDescriminantAnalysis", "DirichletProcessGaussianMixtureModels", "FP-Stream",
                          "FuzzyClustering", "MaximumLikelihood", "NearestNeighbor", "PCA", "SAX", 
                          "SelfOrganizingMaps", "SupportVectorMachines", "Wavelets", "MultipleTechniques",
                          "EnergyInformationSystem", "PatternAnalysis"]

taglistsdict = {"Sector":SectorTags, "AppTagGeneral":ApplicationTags_General, 
                "AppTagSpecific":ApplicationTags_Specific, "TechniqueTagGen":TechniqueTags_General, 
                "TechniqueTagSpec":TechniqueTags_Specific}

# %%
litdata["Manual Tags"].head()
# Out:
# ﻿"Key"
# I4TWCJAN    NaN
# HA9ASFGC    NaN
# TTCWW37J    NaN
# 2DS77FFR    NaN
# NC6C9WWK    NaN
# Name: Manual Tags, dtype: object

# %%
def assigntags(taglist, taglistname, litdata):
    tags = []
    for tagname in taglist:
        df = pd.DataFrame(litdata[litdata["Manual Tags"].str.contains(tagname) == True].index)
        df[taglistname] = tagname
        tags.append(df)
    total = pd.concat(tags)
    total.columns = ["Key", taglistname]
    total.index = total.Key
    total = total.drop(["Key"], axis=1)
    return total

# %%
assigntags(SectorTags, "Sector", litdata).head()
# Out:
#                           Sector
# Key
# PKUJ8VGA  BuildingEnergyAnalysis
# NR2GAKW3  BuildingEnergyAnalysis
# K96TDHIB  BuildingEnergyAnalysis
# GK4QWTI4  BuildingEnergyAnalysis
# SKGSZE2V  BuildingEnergyAnalysis

# %%
tags_df = pd.DataFrame(index=litdata[litdata.Review == False].index)
for taglist in taglistsdict:
    totaltags = assigntags(taglistsdict[taglist], taglist, litdata[litdata.Review == False])
    tags_df = pd.merge(tags_df, totaltags, right_index=True, left_index=True, how='outer')

# %%
tags_df[tags_df.TechniqueTagSpec.isnull()]
# Out:
#          Sector AppTagGeneral TechniqueTagGen TechniqueTagSpec AppTagSpecific
# 8RHTGAXS    NaN           NaN             NaN              NaN            NaN

# %%
litdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, I4TWCJAN to QB7SH8HI
# Data columns (total 87 columns):
# Item Type               125 non-null object
# Publication Year        122 non-null float64
# Author                  122 non-null object
# Title                   125 non-null object
# Publication Title       110 non-null object
# ISBN                    24 non-null object
# ISSN                    23 non-null object
# DOI                     76 non-null object
# Url                     110 non-null object
# Abstract Note           61 non-null object
# Date                    122 non-null object
# Date Added              125 non-null object
# Date Modified           125 non-null object
# Access Date             41 non-null object
# Pages                   95 non-null object
# Num Pages               3 non-null float64
# Issue                   38 non-null object
# Volume                  62 non-null object
# Number Of Volumes       2 non-null object
# Journal Abbreviation    57 non-null object
# Short Title             16 non-null object
# Series                  8 non-null object
# Series Number           2 non-null float64
# Series Text             0 non-null float64
# Series Title            1 non-null object
# Publisher               39 non-null object
# Place                   40 non-null object
# Language                6 non-null object
# Rights                  2 non-null object
# Type                    1 non-null object
# Archive                 0 non-null float64
# Archive Location        0 non-null float64
# Library Catalog         48 non-null object
# Call Number             1 non-null object
# Extra                   2 non-null object
# Notes                   0 non-null float64
# File Attachments        123 non-null object
# Link Attachments        0 non-null float64
# Manual Tags             108 non-null object
# Automatic Tags          4 non-null object
# Editor                  3 non-null object
# Series Editor           0 non-null float64
# Translator              0 non-null float64
# Contributor             0 non-null float64
# Attorney Agent          0 non-null float64
# Book Author             0 non-null float64
# Cast Member             0 non-null float64
# Commenter               0 non-null float64
# Composer                0 non-null float64
# Cosponsor               0 non-null float64
# Counsel                 0 non-null float64
# Interviewer             0 non-null float64
# Producer                0 non-null float64
# Recipient               0 non-null float64
# Reviewed Author         0 non-null float64
# Scriptwriter            0 non-null float64
# Words By                0 non-null float64
# Guest                   0 non-null float64
# Number                  0 non-null float64
# Edition                 1 non-null object
# Running Time            0 non-null float64
# Scale                   0 non-null float64
# Medium                  0 non-null float64
# Artwork Size            0 non-null float64
# Filing Date             0 non-null float64
# Application Number      0 non-null float64
# Assignee                0 non-null float64
# Issuing Authority       0 non-null float64
# Country                 0 non-null float64
# Meeting Name            0 non-null float64
# Conference Name         39 non-null object
# Court                   0 non-null float64
# References              0 non-null float64
# Reporter                0 non-null float64
# Legal Status            0 non-null float64
# Priority Numbers        0 non-null float64
# Programming Language    0 non-null float64
# Version                 0 non-null float64
# System                  0 non-null float64
# Code                    0 non-null float64
# Code Number             0 non-null float64
# Section                 0 non-null float64
# Session                 0 non-null float64
# Committee               0 non-null float64
# History                 0 non-null float64
# Legislative Body        0 non-null float64
# Review                  108 non-null object
# dtypes: float64(51), object(36)
# memory usage: 85.9+ KB

# %%
mergeddata = pd.merge(litdata[["Title", "Publication Title", "Conference Name","Author", "Item Type", "Publication Year"]], tags_df, right_index=True, left_index=True)

# %%
mergeddata.to_csv("tagstest.csv")

# %%
mergeddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 24M5DC6E to ZX4JF3W4
# Data columns (total 11 columns):
# Title                100 non-null object
# Publication Title    95 non-null object
# Conference Name      37 non-null object
# Author               100 non-null object
# Item Type            100 non-null object
# Publication Year     100 non-null float64
# Sector               99 non-null object
# AppTagGeneral        99 non-null object
# TechniqueTagGen      99 non-null object
# TechniqueTagSpec     99 non-null object
# AppTagSpecific       99 non-null object
# dtypes: float64(1), object(10)
# memory usage: 9.4+ KB

# %% [markdown]
# Get the .bibtex notations and combine them as well

# %%
with open('unsupervisedreview.bib') as bibtex_file:
    bibtex_str = bibtex_file.read()

bib_database = bibtexparser.loads(bibtex_str)
bibtex = pd.DataFrame(bib_database.entries)

# %%
bibtex.title = bibtex.title.str.replace("{","")
bibtex.title = bibtex.title.str.replace("}","")

# %%
bibtex.sort(columns="title").reset_index().head()
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    index      ENTRYTYPE                              ID  \
# 0     30        article              de_silva_data_2011
# 1     80   incollection            mansur_learning_2015
# 2    107  inproceedings              shao_temporal_2013
# 3     13        article  adamopoulou_context-aware_2015
# 4     40        article              fan_framework_2015
#
#                                             abstract            address  \
# 0                                                NaN                NaN
# 1                                                NaN               Cham
# 2                                                NaN  Bellevue, WA, USA
# 3  In this paper a building occupancy prediction ...                NaN
# 4  Building Automation System (BAS) plays an impo...                NaN
#
#                                               annote  \
# 0  This paper presents a novel data mining framew...
# 1  This paper proposes an innovation in the manag...
# 2  Non-intrusive appliance load monitoring has em...
# 3  In this paper a building occupancy prediction ...
# 4  This paper presents a generic framework for kn...
#
#                                               author  \
# 0  De Silva, Daswin and Yu, Xinghuo and Alahakoon...
# 1  Mansur, Vitor and Carreira, Paulo and Arsenio,...
# 2  Shao, Huijuan and Marwah, Manish and Ramakrish...
# 3  Adamopoulou, Anna A. and Tryferidis, Athanasio...
# 4          Fan, Cheng and Xiao, Fu and Yan, Chengchu
#
#                                            booktitle copyright  \
# 0                                                NaN       NaN
# 1       Internet of {Things}. {User}-{Centric} {IoT}       NaN
# 2  Proceedings of the {Twenty}-{Seventh} {AAAI} {...       NaN
# 3                                                NaN       NaN
# 4                                                NaN       NaN
#
#                              doi  ...      pages  \
# 0       10.1109/TII.2011.2158844  ...   399--407
# 1                            NaN  ...      9--15
# 2                            NaN  ...       2250
# 3  10.1016/j.enbuild.2015.10.003  ...        NaN
# 4   10.1016/j.autcon.2014.12.006  ...     81--90
#
#                            publisher school series shorttitle  \
# 0                                NaN    NaN    NaN        NaN
# 1  Springer International Publishing    NaN    NaN        NaN
# 2                                NaN    NaN    NaN        NaN
# 3                                NaN    NaN    NaN        NaN
# 4                                NaN    NaN    NaN        NaN
#
#                                                title type     urldate volume  \
# 0  A Data Mining Framework for Electricity Consum...  NaN         NaN      7
# 1  A Learning Approach for Energy Efficiency Opti...  NaN         NaN    150
# 2  A Temporal Motif Mining Approach to Unsupervis...  NaN         NaN    250
# 3  A context-aware method for building occupancy ...  NaN  2015-10-13    NaN
# 4  A framework for knowledge discovery in massive...  NaN  2015-10-01     50
#
#    year
# 0  2011
# 1  2015
# 2  2013
# 3  2015
# 4  2015
#
# [5 rows x 33 columns]

# %%
mergeddata.sort(columns="Title").reset_index().head(2)
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#       index                                              Title  \
# 0  EX6GFAAK  A Data Mining Framework for Electricity Consum...
# 1  JTEUKS2H  A Learning Approach for Energy Efficiency Opti...
#
#                              Publication Title Conference Name  \
# 0  IEEE Transactions on Industrial Informatics             NaN
# 1         Internet of Things. User-Centric IoT             NaN
#
#                                               Author       Item Type  \
# 0  De Silva, Daswin; Yu, Xinghuo; Alahakoon, Damm...  journalArticle
# 1     Mansur, Vitor; Carreira, Paulo; Arsenio, Artur     bookSection
#
#    Publication Year                 Sector AppTagGeneral  \
# 0              2011  ElectricalEngineering    SmartMeter
# 1              2015        ComputerScience    Operations
#
#             TechniqueTagGen                        TechniqueTagSpec  \
# 0  MotifandDiscordDetection  IncrementalSummarizationandPatternChar
# 1                Clustering                                 K-Means
#
#        AppTagSpecific
# 0       LoadProfiling
# 1  OccupancyDetection

# %%
mergeddata = pd.merge(mergeddata.sort(columns="Title"), bibtex[['title','ID']].sort(columns="title"), left_on='Title', right_on='title', how='left')
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# /Users/Clayton/anaconda/lib/python2.7/site-packages/pandas/tools/merge.py:682: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   rlab = rizer.factorize(rk)

# %%
mergeddata.ix[89]
# Out:
# Title                Towards an understanding of campus-scale power...
# Publication Title    Proceedings of the Third ACM Workshop on Embed...
# Conference Name      ACM Workshop on Embedded Sensing Systems for E...
# Author               Bellala, Gowtham; Marwah, Manish; Arlitt, Mart...
# Item Type                                              conferencePaper
# Publication Year                                                  2011
# Sector                                                 ComputerScience
# AppTagGeneral                                        PortfolioAnalysis
# TechniqueTagGen                                       NoveltyDetection
# TechniqueTagSpec                                           MarkovModel
# AppTagSpecific                                               Targeting
# title                Towards an understanding of campus-scale power...
# ID                                                bellala_towards_2011
# Name: 89, dtype: object

# %% [markdown]
# # Create an overview visualization of the domains and subdomains using a hierarchical pie chart

# %%
mergeddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 13 columns):
# Title                100 non-null object
# Publication Title    95 non-null object
# Conference Name      37 non-null object
# Author               100 non-null object
# Item Type            100 non-null object
# Publication Year     100 non-null float64
# Sector               99 non-null object
# AppTagGeneral        99 non-null object
# TechniqueTagGen      99 non-null object
# TechniqueTagSpec     99 non-null object
# AppTagSpecific       99 non-null object
# title                96 non-null object
# ID                   96 non-null object
# dtypes: float64(1), object(12)
# memory usage: 10.9+ KB

# %%
Applications = mergeddata[['AppTagGeneral','AppTagSpecific']]

# %%
Applications.index = Applications.AppTagSpecific

# %%
Applications.head()
# Out:
#                        AppTagGeneral      AppTagSpecific
# AppTagSpecific
# LoadProfiling             SmartMeter       LoadProfiling
# OccupancyDetection        Operations  OccupancyDetection
# Disaggregation            SmartMeter      Disaggregation
# OccupancyDetection        Operations  OccupancyDetection
# WholeBuilding       AnomalyDetection       WholeBuilding

# %%
ApplicationCounts = pd.DataFrame(Applications.AppTagSpecific.value_counts())
ApplicationCounts.columns = ["A"]#.reset_index()
ApplicationCounts = ApplicationCounts.join(Applications).drop_duplicates()
ApplicationCounts = ApplicationCounts.sort(columns='A').sort(columns='AppTagGeneral').reset_index(drop=True)
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
ApplicationCounts
# Out:
#      A      AppTagGeneral          AppTagSpecific
# 0    4   AnomalyDetection               Component
# 1    8   AnomalyDetection               Subsystem
# 2   11   AnomalyDetection           WholeBuilding
# 3    7         Operations         EnergyManagment
# 4    7         Operations      OccupancyDetection
# 5   11         Operations                Controls
# 6    5  PortfolioAnalysis             Classifying
# 7    7  PortfolioAnalysis               Targeting
# 8   13  PortfolioAnalysis        Characterization
# 9    2         SmartMeter          Disaggregation
# 10  11         SmartMeter  CustomerClassification
# 11  13         SmartMeter           LoadProfiling

# %%
ApplicationCounts['A_count'] = ApplicationCounts.A.astype('string')

# %%
ApplicationCounts
# Out:
#      A      AppTagGeneral          AppTagSpecific A_count
# 0    4   AnomalyDetection               Component       4
# 1    8   AnomalyDetection               Subsystem       8
# 2   11   AnomalyDetection           WholeBuilding      11
# 3    7         Operations         EnergyManagment       7
# 4    7         Operations      OccupancyDetection       7
# 5   11         Operations                Controls      11
# 6    5  PortfolioAnalysis             Classifying       5
# 7    7  PortfolioAnalysis               Targeting       7
# 8   13  PortfolioAnalysis        Characterization      13
# 9    2         SmartMeter          Disaggregation       2
# 10  11         SmartMeter  CustomerClassification      11
# 11  13         SmartMeter           LoadProfiling      13

# %%
ApplicationCounts = ApplicationCounts.replace(['WholeBuilding','EnergyManagment','RetrofitAnalysis',
                                               'OccupancyDetection','LoadProfiling','CustomerClassification'],
                                              ['Whole Building','Energy Management','Retrofit Analysis',
                                               'Occupancy\nDetection', 'Load\nProfiling', 'Customer\nClassification'])
ApplicationCounts = ApplicationCounts.replace(['AnomalyDetection','PortfolioAnalysis','SmartMeter'],
                                              ['Anomaly\nDetection','Portfolio\nAnalysis','Smart\nMeter'])

# %%
ApplicationCounts
# Out:
#      A        AppTagGeneral            AppTagSpecific A_count
# 0    4   Anomaly\nDetection                 Component       4
# 1    8   Anomaly\nDetection                 Subsystem       8
# 2   11   Anomaly\nDetection            Whole Building      11
# 3    7           Operations         Energy Management       7
# 4    7           Operations      Occupancy\nDetection       7
# 5   11           Operations                  Controls      11
# 6    5  Portfolio\nAnalysis               Classifying       5
# 7    7  Portfolio\nAnalysis                 Targeting       7
# 8   13  Portfolio\nAnalysis          Characterization      13
# 9    2         Smart\nMeter            Disaggregation       2
# 10  11         Smart\nMeter  Customer\nClassification      11
# 11  13         Smart\nMeter           Load\nProfiling      13

# %%
ApplicationCounts['AppTagSpecNew'] = ApplicationCounts.AppTagSpecific + " - " + ApplicationCounts.A_count

# %%
ApplicationCounts
# Out:
#      A        AppTagGeneral            AppTagSpecific A_count  \
# 0    4   Anomaly\nDetection                 Component       4
# 1    8   Anomaly\nDetection                 Subsystem       8
# 2   11   Anomaly\nDetection            Whole Building      11
# 3    7           Operations         Energy Management       7
# 4    7           Operations      Occupancy\nDetection       7
# 5   11           Operations                  Controls      11
# 6    5  Portfolio\nAnalysis               Classifying       5
# 7    7  Portfolio\nAnalysis                 Targeting       7
# 8   13  Portfolio\nAnalysis          Characterization      13
# 9    2         Smart\nMeter            Disaggregation       2
# 10  11         Smart\nMeter  Customer\nClassification      11
# 11  13         Smart\nMeter           Load\nProfiling      13
#
#                     AppTagSpecNew
# 0                   Component - 4
# 1                   Subsystem - 8
# 2             Whole Building - 11
# 3           Energy Management - 7
# 4        Occupancy\nDetection - 7
# 5                   Controls - 11
# 6                 Classifying - 5
# 7                   Targeting - 7
# 8           Characterization - 13
# 9              Disaggregation - 2
# 10  Customer\nClassification - 11
# 11           Load\nProfiling - 13

# %%
ApplicationCounts = ApplicationCounts.drop(['A_count','AppTagSpecific'], axis=1)
ApplicationCounts = ApplicationCounts[['AppTagGeneral', 'AppTagSpecNew', 'A']]

# %%
goodcolors1 = [u'#006d2c',u'#0868ac',u'#810f7c',u'#b30000']
goodcolors2 = [u'#2ca25f',u'#66c2a4',u'#b2e2e2',
              u'#43a2ca',u'#7bccc4',u'#bae4bc',
              u'#8856a7',u'#8c96c6',u'#b3cde3',
              u'#e34a33',u'#fc8d59',u'#fdcc8a'] #u'#f0f9e8',

# %%
ApplicationCounts
# Out:
#           AppTagGeneral                  AppTagSpecNew   A
# 0    Anomaly\nDetection                  Component - 4   4
# 1    Anomaly\nDetection                  Subsystem - 8   8
# 2    Anomaly\nDetection            Whole Building - 11  11
# 3            Operations          Energy Management - 7   7
# 4            Operations       Occupancy\nDetection - 7   7
# 5            Operations                  Controls - 11  11
# 6   Portfolio\nAnalysis                Classifying - 5   5
# 7   Portfolio\nAnalysis                  Targeting - 7   7
# 8   Portfolio\nAnalysis          Characterization - 13  13
# 9          Smart\nMeter             Disaggregation - 2   2
# 10         Smart\nMeter  Customer\nClassification - 11  11
# 11         Smart\nMeter           Load\nProfiling - 13  13

# %%
# Do the summing to get the values for each layer
def nested_pie(df):

    cols = df.columns.tolist()
    outd = {}
    gb = df.groupby(cols[0], sort=False).sum()
    outd[0] = {'names':gb.index.values, 'values':gb.values}
    for lev in range(1,2):
        gb = df.groupby(cols[:(lev+1)], sort=False).sum()
        outd[lev] = {'names':gb.index.levels[lev][gb.index.labels[lev]].tolist(),
                     'values':gb.values}
    return outd

outd = nested_pie(ApplicationCounts)
diff = 1/2

fig = plt.figure(figsize=(5.5,5.5))

# This first pie chart fill the plot, it's the lowest level
plt.pie(outd[1]['values'], labels=outd[1]['names'], labeldistance=0.8,
        colors=goodcolors2)
ax = plt.gca()
# For each successive plot, change the max radius so that they overlay
for i in np.arange(0,-1,-1):
    ax.pie(outd[i]['values'], labels=outd[i]['names'], 
           radius=np.float(i+1)/2.0, labeldistance=0.45,
           colors=goodcolors1)
ax.set_aspect('equal')

fig.savefig("PieChart.pdf")

# %%
outd
# Out:
# {0: {'names': array(['Anomaly\nDetection', 'Operations', 'Portfolio\nAnalysis',
#          'Smart\nMeter'], dtype=object), 'values': array([[23],
#          [25],
#          [25],
#          [26]])},
#  1: {'names': ['Component - 4',
#    'Subsystem - 8',
#    'Whole Building - 11',
#    'Energy Management - 7',
#    'Occupancy\nDetection - 7',
#    'Controls - 11',
#    'Classifying - 5',
#    'Targeting - 7',
#    'Characterization - 13',
#    'Disaggregation - 2',
#    'Customer\nClassification - 11',
#    'Load\nProfiling - 13'],
#   'values': array([[ 4],
#          [ 8],
#          [11],
#          [ 7],
#          [ 7],
#          [11],
#          [ 5],
#          [ 7],
#          [13],
#          [ 2],
#          [11],
#          [13]])}}

# %% [markdown]
# ## Smart Meter Papers

# %%
def createcatlist(df, listname):
    df = df[df.AppTagGeneral == listname].drop(['Publication Title','AppTagGeneral','Item Type','title', 'Conference Name'],axis=1)
    df = df.replace(['BuildingEnergyAnalysis','ElectricalEngineering','ComputerScience','BuildingSimulation'],
                    ['Building Energy','Elec. Engineering','Computer Science','Building Sim.'])
    
    df = df.replace(["Clustering", "NoveltyDetection", "MotifandDiscordDetection","RuleExtraction", "VisualAnalytics",
                    "Characterization", "Disaggregation"],
                    ["Clustering", "Novelty Detection", "Motif Detection","Rule Extraction", "Visual Analytics",
                    "Characterization", "Disaggregation"])
    
    df = df.replace(['WholeBuilding','EnergyManagment','RetrofitAnalysis',
                    'OccupancyDetection','LoadProfiling','CustomerClassification'],
                    ['Whole Building','Energy Management','Retrofit Analysis',
                    'Occupancy Detection', 'Load Profiling', 'Customer Class.'])
    
    df = df.replace(["AntColony", "Bayesian", "ClassificationandRegressionTree", "DataAssociationRules", 
                    "EmpiricalModeDecomposition", "FourierTransform", "GeneralizedAdditiveModels", 
                      "GeneralizedExtremeStudentizedDeviate", "MarkovModel", "Hierarchical",
                      "IncrementalSummarizationandPatternChar", "K-Means", 
                      "LinearDescriminantAnalysis", "DirichletProcessGaussianMixtureModels", "FP-Stream",
                      "FuzzyClustering", "MaximumLikelihood", "NearestNeighbor", "PCA", "SAX", 
                      "SelfOrganizingMaps", "SupportVectorMachines", "Wavelets", "MultipleTechniques",
                      "EnergyInformationSystem", "PatternAnalysis"],
                    ["Ant Colony", "Bayesian", "CART", "DAR", 
                    "EMC", "Fourier", "GAM",
                      "GESD", "Markov", "Hierarchical",
                      "ISPC", "K-Means", 
                      "LDA", "DPGMM", "FP-Stream",
                      "Fuzzy Clust.", "ML", "Nearest Neighbor", "PCA", "SAX", 
                      "SOM", "SVM", "Wavelets", "Multiple",
                      "EIS", "Patterns"])
    df["Reference"] = "\cite{"+df["ID"]+"}"
    df = df.drop(["ID"], axis=1)
    #df["Ref"] = np.nan
    df.columns = ["Title","Author","Pub. Year","Sector","Type of Analysis","Technique","Sub-Application","Reference"]
    df = df.sort(columns='Pub. Year', ascending=False)
    df_forpaper = df[["Pub. Year","Sub-Application","Sector","Type of Analysis","Technique","Reference"]] #"Title","Author",
    df_forpaper = df_forpaper.reset_index(drop=True)
    df_forpaper = df_forpaper.sort(columns='Pub. Year', ascending=False)
    
    return df_forpaper, df

# %%
smartmeterlist, raw = createcatlist(mergeddata, "SmartMeter")

latexstring = smartmeterlist.to_latex(longtable=True, index=False)
latexstring = latexstring.replace("\\textbackslash","\\")
latexstring = latexstring.replace("\\{","{")
latexstring = latexstring.replace("\\}","}")
latexstring = latexstring.replace("\\_","_")

print latexstring
# Out:
# \begin{longtable}{rlllll}
# \toprule
#  Pub. Year &  Sub-Application &             Sector &   Type of Analysis &   Technique &                           Reference \\
# \midrule
# \endhead
# \midrule
# \multicolumn{3}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
#       2016 &  Customer Class. &    Building Energy &         Clustering &     K-Means &        \cite{jang_variability_2016} \\
#       2015 &   Load Profiling &   Computer Science &         Clustering &     K-Means &     \cite{shahzadeh_improving_2015} \\
#       2015 &  Customer Class. &   Computer Science &   Visual Analytics &    Patterns &               \cite{liu_smas:_2015} \\
#       2015 &   Load Profiling &  Elec. Engineering &         Clustering &         PCA &        \cite{pan_kernel-based_2015} \\
#       2015 &   Load Profiling &  Elec. Engineering &         Clustering &    Multiple &  \cite{panapakidis_evaluation_2015} \\
#       2015 &  Customer Class. &   Computer Science &  Novelty Detection &      Markov &         \cite{fagiani_novelty_2015} \\
#       2014 &   Disaggregation &  Elec. Engineering &    Motif Detection &         SAX &     \cite{reinhardt_powersax:_2014} \\
#       2014 &   Load Profiling &    Building Energy &         Clustering &     K-Means &        \cite{lavin_clustering_2014} \\
#       2014 &   Load Profiling &  Elec. Engineering &         Clustering &     K-Means &            \cite{green_divide_2014} \\
#       2014 &   Load Profiling &   Computer Science &   Visual Analytics &    Patterns &   \cite{jarrah_nezhad_smartd:_2014} \\
#       2014 &  Customer Class. &  Elec. Engineering &   Visual Analytics &    Multiple &              \cite{cakmak_new_2014} \\
#       2013 &   Disaggregation &   Computer Science &    Motif Detection &       DPGMM &           \cite{shao_temporal_2013} \\
#       2013 &   Load Profiling &  Elec. Engineering &         Clustering &  Ant Colony &       \cite{chicco_electrical_2013} \\
#       2013 &  Customer Class. &    Building Energy &         Clustering &    Multiple &       \cite{borgeson_targeted_2013} \\
#       2013 &   Load Profiling &  Elec. Engineering &         Clustering &    Multiple &       \cite{iglesias_analysis_2013} \\
#       2012 &   Load Profiling &  Elec. Engineering &         Clustering &    Multiple &                                 NaN \\
#       2012 &  Customer Class. &      Building Sim. &         Clustering &    Bayesian &  \cite{florita_classification_2012} \\
#       2011 &   Load Profiling &  Elec. Engineering &    Motif Detection &        ISPC &           \cite{de_silva_data_2011} \\
#       2010 &  Customer Class. &  Elec. Engineering &         Clustering &    Multiple &       \cite{bidoki_evaluating_2010} \\
#       2009 &   Load Profiling &   Computer Science &         Clustering &    Multiple &       \cite{gullo_low-voltage_2009} \\
#       2009 &   Load Profiling &  Elec. Engineering &         Clustering &    Multiple &   \cite{rasanen_feature-based_2009} \\
#       2009 &   Load Profiling &  Elec. Engineering &         Clustering &         SVM &          \cite{chicco_support_2009} \\
#       2009 &  Customer Class. &  Elec. Engineering &         Clustering &    Multiple &                                 NaN \\
#       2008 &  Customer Class. &   Computer Science &         Clustering &         SOM &        \cite{rasanen_reducing_2008} \\
#       2006 &  Customer Class. &  Elec. Engineering &         Clustering &         SOM &    \cite{verdu_classification_2006} \\
#       2005 &  Customer Class. &  Elec. Engineering &         Clustering &     K-Means &     \cite{figueiredo_electric_2005} \\
# \end{longtable}
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:39: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
raw
# Out:
#                                                 Title  \
# 94  Variability of electricity load patterns and i...
# 57  Improving load forecast accuracy by clustering...
# 75          SMAS: A smart meter data analytics system
# 58  Kernel-based non-parametric clustering for loa...
# 45  Evaluation of the performance of clustering al...
# 9   A novelty detection approach to identify the o...
# 68  PowerSAX: Fast motif matching in distributed p...
# 27  Clustering time-series energy data from smart ...
# 37  Divide and Conquer K-Means Clustering of Deman...
# 79       SmartD: Smart Meter Data Analytics Dashboard
# 7   A new framework for the analysis of large scal...
# 13  Analysis of Similarity Measures in Times Serie...
# 85  Targeted Efficiency: Using Customer Meter Data...
# 39  Electrical Load Pattern Grouping Based on Cent...
# 2   A Temporal Motif Mining Approach to Unsupervis...
# 90  Typical load profiles in the smart grid contex...
# 24  Classification of Commerical Building Electric...
# 0   A Data Mining Framework for Electricity Consum...
# 44  Evaluating different clustering techniques for...
# 60  Low-voltage electricity customer profiling bas...
# 51  Feature-based clustering for electricity use t...
# 83  Support vector clustering of electrical load p...
# 34  Data mining applications in power systems—Case...
# 73  Reducing energy consumption by using self-orga...
# 25  Classification, Filtering, and Identification ...
# 11  An Electric Energy Consumer Characterization F...
#
#                                                Author  Pub. Year  \
# 94  Jang, Dongsik; Eom, Jiyong; Jae Park, Min; Jeu...       2016
# 57  Shahzadeh, Abbas; Khosravi, Abbas; Nahavandi, ...       2015
# 75               Liu, Xiufeng; Golab, L.; Ilyas, I.F.       2015
# 58   Pan, Erte; Li, Husheng; Song, Lingyang; Han, Zhu       2015
# 45  Panapakidis, Ioannis; Alexiadis, Minas; Papagi...       2015
# 9   Fagiani, Marco; Squartini, Stefano; Severini, ...       2015
# 68            Reinhardt, Andreas; Koessler, Sebastian       2014
# 27                   Lavin, Alexander; Klabjan, Diego       2014
# 37             Green, R.; Staffell, I.; Vasilakos, N.       2014
# 79  Jarrah Nezhad, Aylin; Wijaya, Tri Kurniawan; V...       2014
# 7   Çakmak, Hüseyin Kemâl; Maa\s s, Heiko; Bach, F...       2014
# 13                 Iglesias, Félix; Kastner, Wolfgang       2013
# 85                                      Borgeson, Sam       2013
# 39       Chicco, Gianfranco; Ionel, O-M; Porumb, Radu       2013
# 2   Shao, Huijuan; Marwah, Manish; Ramakrishnan, N...       2013
# 90  Ramos, Sérgio; Duarte, JMM; Soares, João; Vale...       2012
# 24  Florita, Anthony R; Brackney, Larry J; Otanica...       2012
# 0   De Silva, Daswin; Yu, Xinghuo; Alahakoon, Damm...       2011
# 44  Bidoki, S M; Mahmoudi-Kohan, N; Sadreddini, M ...       2010
# 60  Gullo, Francesco; Ponti, Giovanni; Tagarelli, ...       2009
# 51                 Räsänen, Teemu; Kolehmainen, Mikko       2009
# 83                      Chicco, Gianfranco; Ilie, I S       2009
# 34  Vale, Zita A; Ramos, Carlos; Ramos, Sérgio; Pi...       2009
# 73  Räsänen, Teemu; Ruuskanen, Juhani; Kolehmainen...       2008
# 25  Verdu, S V; Garcia, M O; Senabre, C; Marin, A ...       2006
# 11  Figueiredo, V; Rodrigues, F; Vale, Z; Gouveia,...       2005
#
#                Sector   Type of Analysis   Technique  Sub-Application  \
# 94    Building Energy         Clustering     K-Means  Customer Class.
# 57   Computer Science         Clustering     K-Means   Load Profiling
# 75   Computer Science   Visual Analytics    Patterns  Customer Class.
# 58  Elec. Engineering         Clustering         PCA   Load Profiling
# 45  Elec. Engineering         Clustering    Multiple   Load Profiling
# 9    Computer Science  Novelty Detection      Markov  Customer Class.
# 68  Elec. Engineering    Motif Detection         SAX   Disaggregation
# 27    Building Energy         Clustering     K-Means   Load Profiling
# 37  Elec. Engineering         Clustering     K-Means   Load Profiling
# 79   Computer Science   Visual Analytics    Patterns   Load Profiling
# 7   Elec. Engineering   Visual Analytics    Multiple  Customer Class.
# 13  Elec. Engineering         Clustering    Multiple   Load Profiling
# 85    Building Energy         Clustering    Multiple  Customer Class.
# 39  Elec. Engineering         Clustering  Ant Colony   Load Profiling
# 2    Computer Science    Motif Detection       DPGMM   Disaggregation
# 90  Elec. Engineering         Clustering    Multiple   Load Profiling
# 24      Building Sim.         Clustering    Bayesian  Customer Class.
# 0   Elec. Engineering    Motif Detection        ISPC   Load Profiling
# 44  Elec. Engineering         Clustering    Multiple  Customer Class.
# 60   Computer Science         Clustering    Multiple   Load Profiling
# 51  Elec. Engineering         Clustering    Multiple   Load Profiling
# 83  Elec. Engineering         Clustering         SVM   Load Profiling
# 34  Elec. Engineering         Clustering    Multiple  Customer Class.
# 73   Computer Science         Clustering         SOM  Customer Class.
# 25  Elec. Engineering         Clustering         SOM  Customer Class.
# 11  Elec. Engineering         Clustering     K-Means  Customer Class.
#
#                              Reference
# 94        \cite{jang_variability_2016}
# 57     \cite{shahzadeh_improving_2015}
# 75               \cite{liu_smas:_2015}
# 58        \cite{pan_kernel-based_2015}
# 45  \cite{panapakidis_evaluation_2015}
# 9          \cite{fagiani_novelty_2015}
# 68     \cite{reinhardt_powersax:_2014}
# 27        \cite{lavin_clustering_2014}
# 37            \cite{green_divide_2014}
# 79   \cite{jarrah_nezhad_smartd:_2014}
# 7               \cite{cakmak_new_2014}
# 13       \cite{iglesias_analysis_2013}
# 85       \cite{borgeson_targeted_2013}
# 39       \cite{chicco_electrical_2013}
# 2            \cite{shao_temporal_2013}
# 90                                 NaN
# 24  \cite{florita_classification_2012}
# 0            \cite{de_silva_data_2011}
# 44       \cite{bidoki_evaluating_2010}
# 60       \cite{gullo_low-voltage_2009}
# 51   \cite{rasanen_feature-based_2009}
# 83          \cite{chicco_support_2009}
# 34                                 NaN
# 73        \cite{rasanen_reducing_2008}
# 25    \cite{verdu_classification_2006}
# 11     \cite{figueiredo_electric_2005}

# %% [markdown]
# ## Portofolio Analysis

# %%
portfolioanalysis, raw = createcatlist(mergeddata, "PortfolioAnalysis")

latexstring = portfolioanalysis.to_latex(longtable=True, index=False)
latexstring = latexstring.replace("\\textbackslash","\\")
latexstring = latexstring.replace("\\{","{")
latexstring = latexstring.replace("\\}","}")
latexstring = latexstring.replace("\\_","_")

print latexstring
# Out:
# \begin{longtable}{rlllll}
# \toprule
#  Pub. Year &   Sub-Application &             Sector &   Type of Analysis &     Technique &                            Reference \\
# \midrule
# \endhead
# \midrule
# \multicolumn{3}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
#       2016 &         Targeting &    Building Energy &         Clustering &  Fuzzy Clust. &       \cite{schlueter_analysis_2016} \\
#       2016 &         Targeting &    Building Energy &         Clustering &      Multiple &        \cite{geyer_application_2016} \\
#       2015 &  Characterization &  Elec. Engineering &   Visual Analytics &           EIS &       \cite{diong_establishing_2015} \\
#       2015 &  Characterization &    Building Energy &   Visual Analytics &           EIS &    \cite{yarbrough_visualizing_2015} \\
#       2015 &  Characterization &    Building Energy &    Motif Detection &           SAX &         \cite{miller_automated_2015} \\
#       2015 &       Classifying &    Building Energy &         Clustering &      Multiple &                                  NaN \\
#       2015 &  Characterization &      Building Sim. &         Clustering &      Multiple &      \cite{miller_forensically_2015} \\
#       2014 &  Characterization &      Building Sim. &   Visual Analytics &      Patterns &     \cite{georgescu_site-level_2014} \\
#       2014 &       Classifying &  Elec. Engineering &  Novelty Detection &           GAM &  \cite{ploennigs_e2-diagnoser:_2014} \\
#       2014 &       Classifying &    Building Energy &         Clustering &       K-Means &     \cite{heidarinejad_cluster_2014} \\
#       2013 &         Targeting &    Building Energy &    Rule Extraction &           DAR &             \cite{cabrera_data_2013} \\
#       2013 &  Characterization &   Computer Science &   Visual Analytics &      Patterns &           \cite{moran_analysis_2013} \\
#       2012 &         Targeting &    Building Energy &         Clustering &            ML &     \cite{petcharat_assessment_2012} \\
#       2012 &  Characterization &      Building Sim. &         Clustering &       K-Means &            \cite{an_estimation_2012} \\
#       2012 &       Classifying &  Elec. Engineering &         Clustering &      Multiple &     \cite{nikolaou_application_2012} \\
#       2011 &         Targeting &   Computer Science &  Novelty Detection &        Markov &          \cite{bellala_towards_2011} \\
#       2011 &  Characterization &    Building Energy &   Visual Analytics &           EIS &       \cite{lehrer_visualizing_2011} \\
#       2010 &  Characterization &    Building Energy &   Visual Analytics &           EIS &      \cite{granderson_building_2010} \\
#       2010 &         Targeting &    Building Energy &         Clustering &      Multiple &            \cite{gaitani_using_2010} \\
#       2009 &  Characterization &    Building Energy &   Visual Analytics &           EIS &          \cite{lehrer_research_2009} \\
#       2009 &  Characterization &   Computer Science &   Visual Analytics &           EIS &           \cite{agarwal_energy_2009} \\
#       2009 &         Targeting &   Computer Science &         Clustering &            ML &         \cite{sedano_improving_2009} \\
#       2008 &  Characterization &    Building Energy &  Novelty Detection &           PCA &            \cite{lam_principal_2008} \\
#       2007 &       Classifying &    Building Energy &         Clustering &  Fuzzy Clust. &        \cite{santamouris_using_2007} \\
#       2005 &  Characterization &    Building Energy &         Clustering &  Hierarchical &             \cite{seem_pattern_2005} \\
# \end{longtable}
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:39: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
raw
# Out:
#                                                 Title  \
# 12  Analysis of Georeferenced Building Data for th...
# 18  Application of clustering for the development ...
# 41  Establishing the foundation for energy managem...
# 96  Visualizing building energy demand for buildin...
# 20  Automated daily pattern filtering of measured ...
# 55  Identifying energy consumption patterns in the...
# 53  Forensically discovering simulation feedback k...
# 78  Site-Level Energy Monitoring and Analysis usin...
# 99  e2-Diagnoser: A System for Monitoring, Forecas...
# 26  Cluster analysis of simulated energy use for L...
# 33  Data association mining for identifying lighti...
# 14  Analysis of electricity bills using visual con...
# 42  Estimation of Thermal Parameters of Buildings ...
# 65  On the Application of Clustering Techniques fo...
# 19  Assessment of potential energy saving using cl...
# 89  Towards an understanding of campus-scale power...
# 95  Visualizing Energy Information in Commercial B...
# 23  Building energy information systems: user case...
# 93  Using principal component and cluster analysis...
# 74  Research Scoping Report: Visualizing Informati...
# 87  The energy dashboard: improving the visibility...
# 56  Improving energy efficiency in buildings using...
# 70  Principal component analysis of electricity us...
# 91  Using intelligent clustering techniques to cla...
# 67  Pattern recognition algorithm for determining ...
#
#                                                Author  Pub. Year  \
# 12                Schlueter, A.; Geyer, P.; Cisar, S.       2016
# 18       Geyer, Philipp; Schlüter, Arno; Cisar, Sasha       2016
# 41                     Diong, B.; Zheng, G.; Ginn, M.       2015
# 96  Yarbrough, I.; Sun, Q.; Reeves, D. C.; Hackman...       2015
# 20     Miller, Clayton; Nagy, Zoltán; Schlueter, Arno       2015
# 55  Pieri, Stella Panayiota; IoannisTzouvadakis; S...       2015
# 53                   Miller, Clayton; Schlueter, Arno       2015
# 78                             Georgescu, M; Mezic, I       2014
# 99  Ploennigs, Joern; Chen, Bei; Palmes, Paulito; ...       2014
# 26  Heidarinejad, Mohammad; Dahlhausen, Matthew; M...       2014
# 33       Cabrera, David F Motta; Zareipour, Hamidreza       2013
# 14  Morán, A; Fuertes, J J; Domínguez, M; Prada, M...       2013
# 42  An, Lianjun; Horesh, Raya; Chae, Young Tae; Le...       2012
# 65  Nikolaou, Triantafyllia G; Kolokotsa, Dionysia...       2012
# 19  Petcharat, Siriwarin; Chungpaibulpatana, Supac...       2012
# 89  Bellala, Gowtham; Marwah, Manish; Arlitt, Mart...       2011
# 95                     Lehrer, David; Vasudev, Janani       2011
# 23  Granderson, Jessica; Piette, Mary Ann; Ghatika...       2010
# 93  Gaitani, N; Lehmann, C; Santamouris, M; Mihala...       2010
# 74                                      Lehrer, David       2009
# 87    Agarwal, Yuvraj; Weng, Thomas; Gupta, Rajesh K.       2009
# 56  Sedano, Javier; Villar, José Ramón; Curiel, Le...       2009
# 70  Lam, Joseph C; Wan, Kevin K W; Cheung, K L; Ya...       2008
# 91  Santamouris, M; Mihalakakou, G; Patargias, P; ...       2007
# 67                                       Seem, John E       2005
#
#                Sector   Type of Analysis     Technique   Sub-Application  \
# 12    Building Energy         Clustering  Fuzzy Clust.         Targeting
# 18    Building Energy         Clustering      Multiple         Targeting
# 41  Elec. Engineering   Visual Analytics           EIS  Characterization
# 96    Building Energy   Visual Analytics           EIS  Characterization
# 20    Building Energy    Motif Detection           SAX  Characterization
# 55    Building Energy         Clustering      Multiple       Classifying
# 53      Building Sim.         Clustering      Multiple  Characterization
# 78      Building Sim.   Visual Analytics      Patterns  Characterization
# 99  Elec. Engineering  Novelty Detection           GAM       Classifying
# 26    Building Energy         Clustering       K-Means       Classifying
# 33    Building Energy    Rule Extraction           DAR         Targeting
# 14   Computer Science   Visual Analytics      Patterns  Characterization
# 42      Building Sim.         Clustering       K-Means  Characterization
# 65  Elec. Engineering         Clustering      Multiple       Classifying
# 19    Building Energy         Clustering            ML         Targeting
# 89   Computer Science  Novelty Detection        Markov         Targeting
# 95    Building Energy   Visual Analytics           EIS  Characterization
# 23    Building Energy   Visual Analytics           EIS  Characterization
# 93    Building Energy         Clustering      Multiple         Targeting
# 74    Building Energy   Visual Analytics           EIS  Characterization
# 87   Computer Science   Visual Analytics           EIS  Characterization
# 56   Computer Science         Clustering            ML         Targeting
# 70    Building Energy  Novelty Detection           PCA  Characterization
# 91    Building Energy         Clustering  Fuzzy Clust.       Classifying
# 67    Building Energy         Clustering  Hierarchical  Characterization
#
#                               Reference
# 12       \cite{schlueter_analysis_2016}
# 18        \cite{geyer_application_2016}
# 41       \cite{diong_establishing_2015}
# 96    \cite{yarbrough_visualizing_2015}
# 20         \cite{miller_automated_2015}
# 55                                  NaN
# 53      \cite{miller_forensically_2015}
# 78     \cite{georgescu_site-level_2014}
# 99  \cite{ploennigs_e2-diagnoser:_2014}
# 26     \cite{heidarinejad_cluster_2014}
# 33             \cite{cabrera_data_2013}
# 14           \cite{moran_analysis_2013}
# 42            \cite{an_estimation_2012}
# 65     \cite{nikolaou_application_2012}
# 19     \cite{petcharat_assessment_2012}
# 89          \cite{bellala_towards_2011}
# 95       \cite{lehrer_visualizing_2011}
# 23      \cite{granderson_building_2010}
# 93            \cite{gaitani_using_2010}
# 74          \cite{lehrer_research_2009}
# 87           \cite{agarwal_energy_2009}
# 56         \cite{sedano_improving_2009}
# 70            \cite{lam_principal_2008}
# 91        \cite{santamouris_using_2007}
# 67             \cite{seem_pattern_2005}

# %% [markdown]
# ## Operations

# %%
operations, raw = createcatlist(mergeddata, "Operations")

latexstring = operations.to_latex(longtable=True, index=False)
latexstring = latexstring.replace("\\textbackslash","\\")
latexstring = latexstring.replace("\\{","{")
latexstring = latexstring.replace("\\}","}")
latexstring = latexstring.replace("\\_","_")

print latexstring
# Out:
# \begin{longtable}{rlllll}
# \toprule
#  Pub. Year &      Sub-Application &             Sector &  Type of Analysis & Technique &                                   Reference \\
# \midrule
# \endhead
# \midrule
# \multicolumn{3}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
#       2016 &  Occupancy Detection &    Building Energy &   Rule Extraction &  Wavelets &                 \cite{ahn_correlation_2016} \\
#       2015 &  Occupancy Detection &   Computer Science &        Clustering &   K-Means &                 \cite{mansur_learning_2015} \\
#       2015 &  Occupancy Detection &    Building Energy &   Rule Extraction &    Markov &       \cite{adamopoulou_context-aware_2015} \\
#       2015 &    Energy Management &    Building Energy &   Rule Extraction &       DAR &                    \cite{fan_temporal_2015} \\
#       2015 &    Energy Management &    Building Energy &  Visual Analytics &       EIS &                    \cite{gayeski_data_2015} \\
#       2015 &  Occupancy Detection &    Building Energy &   Rule Extraction &  Multiple &                  \cite{doca_occupancy_2015} \\
#       2015 &             Controls &  Elec. Engineering &   Motif Detection &       SAX &                   \cite{habib_finding_2015} \\
#       2014 &    Energy Management &    Building Energy &   Rule Extraction &       DAR &                       \cite{xiao_data_2014} \\
#       2014 &             Controls &  Elec. Engineering &   Rule Extraction &       SVM &               \cite{domahidi_learning_2014} \\
#       2013 &    Energy Management &  Elec. Engineering &  Visual Analytics &  Patterns &               \cite{lange_discovering_2013} \\
#       2013 &             Controls &    Building Energy &        Clustering &  Multiple &                \cite{bogen_evaluating_2013} \\
#       2013 &    Energy Management &      Building Sim. &   Rule Extraction &       DAR &                                         NaN \\
#       2013 &             Controls &      Building Sim. &   Rule Extraction &       DAR &        \cite{may-ostendorp_extraction_2013} \\
#       2013 &             Controls &    Building Energy &        Clustering &   K-Means &                  \cite{fan_prediction_2013} \\
#       2013 &             Controls &   Computer Science &        Clustering &       EMC &                    \cite{hong_towards_2013} \\
#       2012 &    Energy Management &  Elec. Engineering &  Visual Analytics &  Patterns &                    \cite{lange_energy_2012} \\
#       2012 &  Occupancy Detection &  Elec. Engineering &   Motif Detection &        ML &        \cite{thanayankizil_softgreen:_2012} \\
#       2011 &             Controls &    Building Energy &   Rule Extraction &       DAR &  \cite{may-ostendorp_model-predictive_2011} \\
#       2011 &    Energy Management &    Building Energy &  Visual Analytics &       EIS &             \cite{duarte_prioritizing_2011} \\
#       2011 &  Occupancy Detection &   Computer Science &        Clustering &  Multiple &                  \cite{augello_sensor_2011} \\
#       2011 &  Occupancy Detection &      Building Sim. &   Motif Detection &    Markov &                   \cite{dong_building_2011} \\
#       2011 &             Controls &   Computer Science &  Visual Analytics &  Patterns &                 \cite{hao_visualizing_2011} \\
#       2010 &             Controls &   Computer Science &   Motif Detection &       SAX &                    \cite{patnaik_data_2010} \\
#       2009 &             Controls &   Computer Science &   Motif Detection &       SAX &             \cite{patnaik_sustainable_2009} \\
#       2008 &             Controls &  Elec. Engineering &        Clustering &  Multiple &         \cite{kusiak_clustering-based_2008} \\
# \end{longtable}
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:39: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
raw
# Out:
#                                                 Title  \
# 30  Correlation between occupants and energy consu...
# 1   A Learning Approach for Energy Efficiency Opti...
# 3   A context-aware method for building occupancy ...
# 86  Temporal Knowledge Discovery in Big BAS Data f...
# 32  Data and Interfaces for Advanced Building Oper...
# 64  Occupancy schedules learning process through a...
# 52  Finding the Different Patterns in Buildings Da...
# 35  Data mining in building automation system for ...
# 59  Learning decision rules for energy efficient b...
# 88  Towards Automatic Spatial Verification of Sens...
# 69  Prediction of Chiller Power Consumption Using ...
# 48  Extraction of supervisory building control rul...
# 47  Extracting knowledge from building-related dat...
# 43  Evaluating a data clustering approach for life...
# 36  Discovering unexpected information using a bui...
# 40  Energy Consumption Improvement Through a Visua...
# 80  Softgreen: Towards energy management of green ...
# 63  Model-predictive control of mixed-mode buildin...
# 71  Prioritizing and Visualizing Energy Management...
# 76  Sensor mining for user behavior profiling in i...
# 22  Building energy and comfort management through...
# 97  Visualizing frequent patterns in large multiva...
# 31  Data Mining for Modeling Chiller Systems in Da...
# 84  Sustainable Operation and Management of Data C...
# 28  Clustering-Based Performance Optimization of t...
#
#                                                Author  Pub. Year  \
# 30                       Ahn, Ki-Uhn; Park, Cheol-Soo       2016
# 1      Mansur, Vitor; Carreira, Paulo; Arsenio, Artur       2015
# 3   Adamopoulou, Anna A.; Tryferidis, Athanasios M...       2015
# 86    Fan, Cheng; Xiao, Fu; Madsen, Henrik; Wang, Dan       2015
# 32  Gayeski, Nicholas; Kleindienst, Sian; Gagne, J...       2015
# 64                      D’Oca, Simona; Hong, Tianzhen       2015
# 52                              Habib, U.; Zucker, G.       2015
# 35                               Xiao, Fu; Fan, Cheng       2014
# 59  Domahidi, Alexander; Ullmann, Fabian; Morari, ...       2014
# 88  Hong, Dezhi; Ortiz, Jorge; Whitehouse, Kamin; ...       2013
# 69               Fan, Cheng; Xiao, Fu; Shengwei, Wang       2013
# 48  May-Ostendorp, Peter T; Henze, Gregor P; Rajag...       2013
# 47  Yu, Zhun Jerry; Fung, Benjamin C M; Haghighat,...       2013
# 43          Bogen, A C; Rashid, M; East, E W; Ross, J       2013
# 36       Lange, B; Rodriguez, N; Puech, W; Vasques, X       2013
# 40    Lange, Benoit; Rodriguez, Nancy; Puech, William       2012
# 80  Thanayankizil, L V; Ghai, S K; Chakraborty, D;...       2012
# 63  May-Ostendorp, Peter; Henze, Gregor P; Corbin,...       2011
# 71  Duarte, Carlos; Acker, Brad; Grosshans, Ray; M...       2011
# 76  Augello, Agnese; Ortolani, Marco; Re, G Lo; Ga...       2011
# 22                          Dong, Bing; Lam, Khee Poh       2011
# 97  Hao, M.; Marwah, M.; Janetzko, H.; Sharma, R.;...       2011
# 31  Patnaik, Debprakash; Marwah, Manish; Sharma, R...       2010
# 84  Patnaik, Debprakash; Marwah, Manish; Sharma, R...       2009
# 28                          Kusiak, Andrew; Song, Zhe       2008
#
#                Sector  Type of Analysis Technique      Sub-Application  \
# 30    Building Energy   Rule Extraction  Wavelets  Occupancy Detection
# 1    Computer Science        Clustering   K-Means  Occupancy Detection
# 3     Building Energy   Rule Extraction    Markov  Occupancy Detection
# 86    Building Energy   Rule Extraction       DAR    Energy Management
# 32    Building Energy  Visual Analytics       EIS    Energy Management
# 64    Building Energy   Rule Extraction  Multiple  Occupancy Detection
# 52  Elec. Engineering   Motif Detection       SAX             Controls
# 35    Building Energy   Rule Extraction       DAR    Energy Management
# 59  Elec. Engineering   Rule Extraction       SVM             Controls
# 88   Computer Science        Clustering       EMC             Controls
# 69    Building Energy        Clustering   K-Means             Controls
# 48      Building Sim.   Rule Extraction       DAR             Controls
# 47      Building Sim.   Rule Extraction       DAR    Energy Management
# 43    Building Energy        Clustering  Multiple             Controls
# 36  Elec. Engineering  Visual Analytics  Patterns    Energy Management
# 40  Elec. Engineering  Visual Analytics  Patterns    Energy Management
# 80  Elec. Engineering   Motif Detection        ML  Occupancy Detection
# 63    Building Energy   Rule Extraction       DAR             Controls
# 71    Building Energy  Visual Analytics       EIS    Energy Management
# 76   Computer Science        Clustering  Multiple  Occupancy Detection
# 22      Building Sim.   Motif Detection    Markov  Occupancy Detection
# 97   Computer Science  Visual Analytics  Patterns             Controls
# 31   Computer Science   Motif Detection       SAX             Controls
# 84   Computer Science   Motif Detection       SAX             Controls
# 28  Elec. Engineering        Clustering  Multiple             Controls
#
#                                      Reference
# 30                 \cite{ahn_correlation_2016}
# 1                  \cite{mansur_learning_2015}
# 3        \cite{adamopoulou_context-aware_2015}
# 86                    \cite{fan_temporal_2015}
# 32                    \cite{gayeski_data_2015}
# 64                  \cite{doca_occupancy_2015}
# 52                   \cite{habib_finding_2015}
# 35                       \cite{xiao_data_2014}
# 59               \cite{domahidi_learning_2014}
# 88                    \cite{hong_towards_2013}
# 69                  \cite{fan_prediction_2013}
# 48        \cite{may-ostendorp_extraction_2013}
# 47                                         NaN
# 43                \cite{bogen_evaluating_2013}
# 36               \cite{lange_discovering_2013}
# 40                    \cite{lange_energy_2012}
# 80        \cite{thanayankizil_softgreen:_2012}
# 63  \cite{may-ostendorp_model-predictive_2011}
# 71             \cite{duarte_prioritizing_2011}
# 76                  \cite{augello_sensor_2011}
# 22                   \cite{dong_building_2011}
# 97                 \cite{hao_visualizing_2011}
# 31                    \cite{patnaik_data_2010}
# 84             \cite{patnaik_sustainable_2009}
# 28         \cite{kusiak_clustering-based_2008}

# %% [markdown]
# # Anomaly Detection Papers
#
# We need a table of the Anomaly Detection papers

# %%
mergeddata = mergeddata.reset_index(drop=True)

# %%
mergeddata.head()
# Out:
#                                                Title  \
# 0  A Data Mining Framework for Electricity Consum...
# 1  A Learning Approach for Energy Efficiency Opti...
# 2  A Temporal Motif Mining Approach to Unsupervis...
# 3  A context-aware method for building occupancy ...
# 4  A framework for knowledge discovery in massive...
#
#                                    Publication Title  \
# 0        IEEE Transactions on Industrial Informatics
# 1               Internet of Things. User-Centric IoT
# 2  Proceedings of the Twenty-Seventh AAAI Confere...
# 3                               Energy and Buildings
# 4                         Automation in Construction
#
#                                 Conference Name  \
# 0                                           NaN
# 1                                           NaN
# 2  Conference on Artificial Intelligence (AAAI)
# 3                                           NaN
# 4                                           NaN
#
#                                               Author        Item Type  \
# 0  De Silva, Daswin; Yu, Xinghuo; Alahakoon, Damm...   journalArticle
# 1     Mansur, Vitor; Carreira, Paulo; Arsenio, Artur      bookSection
# 2  Shao, Huijuan; Marwah, Manish; Ramakrishnan, N...  conferencePaper
# 3  Adamopoulou, Anna A.; Tryferidis, Athanasios M...   journalArticle
# 4                Fan, Cheng; Xiao, Fu; Yan, Chengchu   journalArticle
#
#    Publication Year                  Sector     AppTagGeneral  \
# 0              2011   ElectricalEngineering        SmartMeter
# 1              2015         ComputerScience        Operations
# 2              2013         ComputerScience        SmartMeter
# 3              2015  BuildingEnergyAnalysis        Operations
# 4              2015  BuildingEnergyAnalysis  AnomalyDetection
#
#             TechniqueTagGen                        TechniqueTagSpec  \
# 0  MotifandDiscordDetection  IncrementalSummarizationandPatternChar
# 1                Clustering                                 K-Means
# 2  MotifandDiscordDetection   DirichletProcessGaussianMixtureModels
# 3            RuleExtraction                             MarkovModel
# 4          NoveltyDetection                    DataAssociationRules
#
#        AppTagSpecific                                              title  \
# 0       LoadProfiling  A Data Mining Framework for Electricity Consum...
# 1  OccupancyDetection  A Learning Approach for Energy Efficiency Opti...
# 2      Disaggregation  A Temporal Motif Mining Approach to Unsupervis...
# 3  OccupancyDetection  A context-aware method for building occupancy ...
# 4       WholeBuilding  A framework for knowledge discovery in massive...
#
#                                ID
# 0              de_silva_data_2011
# 1            mansur_learning_2015
# 2              shao_temporal_2013
# 3  adamopoulou_context-aware_2015
# 4              fan_framework_2015

# %%
anomalylist, raw = createcatlist(mergeddata, "AnomalyDetection")
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:39: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#print anomalylist

# %%
latexstring = anomalylist.to_latex(longtable=True, index=False)
latexstring = latexstring.replace("\\textbackslash","\\")
latexstring = latexstring.replace("\\{","{")
latexstring = latexstring.replace("\\}","}")
latexstring = latexstring.replace("\\_","_")

# %%
print latexstring
# Out:
# \begin{longtable}{rlllll}
# \toprule
#  Pub. Year & Sub-Application &             Sector &   Type of Analysis &         Technique &                           Reference \\
# \midrule
# \endhead
# \midrule
# \multicolumn{3}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
#       2015 &  Whole Building &    Building Energy &  Novelty Detection &               DAR &           \cite{fan_framework_2015} \\
#       2015 &  Whole Building &    Building Energy &  Novelty Detection &          Multiple &         \cite{capozzoli_fault_2015} \\
#       2015 &       Subsystem &  Elec. Engineering &  Novelty Detection &               DAR &           \cite{sun_efficient_2015} \\
#       2014 &       Subsystem &    Building Energy &  Novelty Detection &               PCA &          \cite{li_model-based_2014} \\
#       2014 &  Whole Building &  Elec. Engineering &  Novelty Detection &               GAM &        \cite{chen_statistical_2014} \\
#       2014 &  Whole Building &    Building Energy &         Clustering &           K-Means &          \cite{chou_real-time_2014} \\
#       2014 &       Subsystem &   Computer Science &  Novelty Detection &          Multiple &     \cite{wijayasekara_mining_2014} \\
#       2014 &       Subsystem &      Building Sim. &  Novelty Detection &               PCA &      \cite{le_cam_application_2014} \\
#       2013 &  Whole Building &  Elec. Engineering &  Novelty Detection &               GAM &    \cite{ploennigs_exploiting_2013} \\
#       2013 &  Whole Building &   Computer Science &   Visual Analytics &          Patterns &        \cite{janetzko_anomaly_2013} \\
#       2013 &       Component &   Computer Science &  Novelty Detection &               EMC &         \cite{fontugne_mining_2013} \\
#       2013 &  Whole Building &   Computer Science &  Novelty Detection &          Multiple &          \cite{fontugne_strip_2013} \\
#       2012 &       Subsystem &  Elec. Engineering &  Novelty Detection &  Nearest Neighbor &     \cite{linda_computational_2012} \\
#       2012 &       Component &    Building Energy &  Novelty Detection &          Wavelets &               \cite{zhu_fault_2012} \\
#       2012 &  Whole Building &  Elec. Engineering &  Novelty Detection &           Fourier &          \cite{wrinch_anomaly_2012} \\
#       2012 &       Component &    Building Energy &    Rule Extraction &               DAR &                \cite{yu_novel_2012} \\
#       2010 &  Whole Building &   Computer Science &  Novelty Detection &              CART &              \cite{liu_method_2010} \\
#       2010 &  Whole Building &      Building Sim. &         Clustering &      Hierarchical &         \cite{jacob_black-box_2010} \\
#       2010 &       Subsystem &    Building Energy &  Novelty Detection &               PCA &       \cite{wang_system-level_2010} \\
#       2010 &       Subsystem &   Computer Science &   Visual Analytics &          Patterns &        \cite{forlines_wakame:_2010} \\
#       2008 &       Subsystem &  Elec. Engineering &  Novelty Detection &               LDA &  \cite{yoshida_identification_2008} \\
#       2006 &  Whole Building &    Building Energy &  Novelty Detection &              GESD &              \cite{seem_using_2006} \\
#       2005 &       Component &    Building Energy &  Novelty Detection &               PCA &       \cite{wang_sensor-fault_2005} \\
# \end{longtable}

# %% [markdown]
# Create visualization

# %%
anomalylist.head()
# Out:
#    Pub. Year Sub-Application             Sector   Type of Analysis Technique  \
# 0       2015  Whole Building    Building Energy  Novelty Detection       DAR
# 2       2015  Whole Building    Building Energy  Novelty Detection  Multiple
# 1       2015       Subsystem  Elec. Engineering  Novelty Detection       DAR
# 3       2014       Subsystem    Building Energy  Novelty Detection       PCA
# 4       2014  Whole Building  Elec. Engineering  Novelty Detection       GAM
#
#                       Reference
# 0     \cite{fan_framework_2015}
# 2   \cite{capozzoli_fault_2015}
# 1     \cite{sun_efficient_2015}
# 3    \cite{li_model-based_2014}
# 4  \cite{chen_statistical_2014}

# %%
#mergeddata

# %% [markdown]
# ## Explore Publications
#
# These are graphics to go in either the introduction OR the discussion at the end to summarize the data

# %%
mergeddata.Sector.unique()
# Out:
# array(['ElectricalEngineering', 'ComputerScience',
#        'BuildingEnergyAnalysis', 'BuildingSimulation', nan], dtype=object)

# %%
def cleannamesforplotting(df):
    df = df.replace(['ComputerScience', 'ElectricalEngineering','BuildingEnergyAnalysis', 'BuildingSimulation'],
                    ['Computer Science', 'Electrical Engineering','Building Energy Analysis', 'Building Simulation'])
    
    df = df.replace(["Clustering", "NoveltyDetection", "MotifandDiscordDetection","RuleExtraction", "VisualAnalytics"],
                    ["Clustering", "Novelty Detection", "Motif Detection","Rule Extraction", "Visual Analytics"])
    
    df = df.replace(['WholeBuilding','EnergyManagment','RetrofitAnalysis',
                    'OccupancyDetection','LoadProfiling','CustomerClassification'],
                    ['Whole Building','Energy Management','Retrofit Analysis',
                    'Occupancy Detection', 'Load Profiling', 'Customer Class.'])
    
    df = df.replace(["AntColony", "Bayesian", "ClassificationandRegressionTree", "DataAssociationRules", 
                    "EmpiricalModeDecomposition", "FourierTransform", "GeneralizedAdditiveModels", 
                      "GeneralizedExtremeStudentizedDeviate", "MarkovModel", "Hierarchical",
                      "IncrementalSummarizationandPatternChar", "K-Means", 
                      "LinearDescriminantAnalysis", "DirichletProcessGaussianMixtureModels", "FP-Stream",
                      "FuzzyClustering", "MaximumLikelihood", "NearestNeighbor", "PCA", "SAX", 
                      "SelfOrganizingMaps", "SupportVectorMachines", "Wavelets", "MultipleTechniques",
                      "EnergyInformationSystem", "PatternAnalysis"],
                    ["Ant Colony", "Bayesian", "Classification and Regression Tree(CART)", "Data Assocation Rules (DAR)", 
                    "Empirical Mode Decomposition (EMC)", "Fourier Transform", "Generalized Additive Models (GAM)",
                      "Generalized Extreme Studentized Deviate (GESD)", "Markov Models", "Hierarchical Clustering",
                      "Incremental Summarization and Pattern Char. (ISPC)", "K-Means", 
                      "Linear Descriminant Analysis (LDA)", "Dirichlet Process Gaussian Mixture Models (DPGMM)", "FP-Stream",
                      "Fuzzy Clustering", "Maximum Likelihood (ML)", "Nearest Neighbor", "Principal Component Analysis (PCA)", "Symbolic Aggregate Approximation (SAX)", 
                      "Self-Organizing Maps (SOM)", "Support Vector Machines (SVM)", "Wavelets", "Multiple Techniques",
                      "Energy Information Systems (EIS)", "Pattern Analysis"])
    return df

# %%
mergeddata = cleannamesforplotting(mergeddata)

# %%
mergeddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 13 columns):
# Title                100 non-null object
# Publication Title    95 non-null object
# Conference Name      37 non-null object
# Author               100 non-null object
# Item Type            100 non-null object
# Publication Year     100 non-null float64
# Sector               99 non-null object
# AppTagGeneral        99 non-null object
# TechniqueTagGen      99 non-null object
# TechniqueTagSpec     99 non-null object
# AppTagSpecific       99 non-null object
# title                96 non-null object
# ID                   96 non-null object
# dtypes: float64(1), object(12)
# memory usage: 10.9+ KB

# %%
mergeddata["Publication Year"] = mergeddata["Publication Year"].astype("int")

# %%
current_palette = sns.color_palette("cubehelix", 4)
sns.set_palette(current_palette)

# %%
sector_year_group = mergeddata.groupby(['Publication Year','Sector']).count()

fig = plt.figure()
ax = sector_year_group.unstack()['Title'].plot(kind='bar',stacked=True, figsize=(3,3), title="Annual Publication Breakdown", colormap = 'viridis')
ax.set_ylabel("Number of Publications")

plt.savefig("PublicationYear.pdf",bbox_inches='tight')

# %%
#mergeddata.head()

# %%
fig = plt.figure()
colors = "viridis"
#sns.set_palette("inferno",4)

stackedbars = mergeddata[(mergeddata["Item Type"] == 'conferencePaper')].groupby(['Conference Name','Sector']).count()
to_plot = stackedbars.unstack()['Title']

plotindex = pd.Series(to_plot.index)
plotindex = plotindex.str.replace("International","Int.")
plotindex = plotindex.str.replace("Conference","Conf.")
plotindex = plotindex.str.replace("Systems","Sys.")
plotindex = plotindex.str.replace("Simulation","Sim.")
plotindex = plotindex.str.replace("Workshop","Wkshp.")
plotindex = plotindex.str.replace("Indoor Air Quality","IAQ")


to_plot.index = plotindex

ax = to_plot.ix[to_plot.sum(axis=1).order().index].plot(kind='barh',stacked=True, figsize=(3,5), title="Conference Publication Breakdown", colormap = colors)
ax.set_xlabel("Number of Publications")
ax.xaxis.set_ticks([0,1,2,3,4])


plt.savefig("ConferencePubs.pdf",bbox_inches='tight');
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: order is deprecated, use sort_values(...)

# %%
fig = plt.figure()

stackedbars = mergeddata[(mergeddata["Item Type"] == 'journalArticle')].groupby(['Publication Title','Sector']).count()
to_plot = stackedbars.unstack()['Title']
ax = to_plot.ix[to_plot.sum(axis=1).order().index].plot(kind='barh',stacked=True, figsize=(3,4), title="Journal Publication Breakdown", colormap = colors)
ax.set_xlabel("Number of Publications")

plt.savefig("JournalPubs_2.pdf",bbox_inches='tight');
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: order is deprecated, use sort_values(...)

# %%
mergeddata.head()
# Out:
#                                                Title  \
# 0  A Data Mining Framework for Electricity Consum...
# 1  A Learning Approach for Energy Efficiency Opti...
# 2  A Temporal Motif Mining Approach to Unsupervis...
# 3  A context-aware method for building occupancy ...
# 4  A framework for knowledge discovery in massive...
#
#                                    Publication Title  \
# 0        IEEE Transactions on Industrial Informatics
# 1               Internet of Things. User-Centric IoT
# 2  Proceedings of the Twenty-Seventh AAAI Confere...
# 3                               Energy and Buildings
# 4                         Automation in Construction
#
#                                 Conference Name  \
# 0                                           NaN
# 1                                           NaN
# 2  Conference on Artificial Intelligence (AAAI)
# 3                                           NaN
# 4                                           NaN
#
#                                               Author        Item Type  \
# 0  De Silva, Daswin; Yu, Xinghuo; Alahakoon, Damm...   journalArticle
# 1     Mansur, Vitor; Carreira, Paulo; Arsenio, Artur      bookSection
# 2  Shao, Huijuan; Marwah, Manish; Ramakrishnan, N...  conferencePaper
# 3  Adamopoulou, Anna A.; Tryferidis, Athanasios M...   journalArticle
# 4                Fan, Cheng; Xiao, Fu; Yan, Chengchu   journalArticle
#
#    Publication Year                    Sector     AppTagGeneral  \
# 0              2011    Electrical Engineering        SmartMeter
# 1              2015          Computer Science        Operations
# 2              2013          Computer Science        SmartMeter
# 3              2015  Building Energy Analysis        Operations
# 4              2015  Building Energy Analysis  AnomalyDetection
#
#      TechniqueTagGen                                   TechniqueTagSpec  \
# 0    Motif Detection  Incremental Summarization and Pattern Char. (I...
# 1         Clustering                                            K-Means
# 2    Motif Detection  Dirichlet Process Gaussian Mixture Models (DPGMM)
# 3    Rule Extraction                                      Markov Models
# 4  Novelty Detection                        Data Assocation Rules (DAR)
#
#         AppTagSpecific                                              title  \
# 0       Load Profiling  A Data Mining Framework for Electricity Consum...
# 1  Occupancy Detection  A Learning Approach for Energy Efficiency Opti...
# 2       Disaggregation  A Temporal Motif Mining Approach to Unsupervis...
# 3  Occupancy Detection  A context-aware method for building occupancy ...
# 4       Whole Building  A framework for knowledge discovery in massive...
#
#                                ID
# 0              de_silva_data_2011
# 1            mansur_learning_2015
# 2              shao_temporal_2013
# 3  adamopoulou_context-aware_2015
# 4              fan_framework_2015

# %%
current_palette = sns.cubehelix_palette(5, rot=-.75)
sns.set_palette(current_palette)

# %%
fig = plt.figure()

stackedbars = mergeddata.groupby(['TechniqueTagSpec','TechniqueTagGen']).count()
to_plot = stackedbars.unstack()['Title']
to_plot.columns.name = "Type of Analysis"
ax = to_plot.ix[to_plot.sum(axis=1).order().index].plot(kind='barh',stacked=True, figsize=(4,4), title="Techniques Breakdown", colormap = "magma")
ax.set_xlabel("Number of Publications")
ax.set_ylabel("Techniques")

plt.savefig("Techniques.pdf",bbox_inches='tight');
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: order is deprecated, use sort_values(...)

# %% [markdown]
# ## create bar charts using a manually tagged data

# %%
mergeddata
# Out:
#                                                 Title  \
# 0   A Data Mining Framework for Electricity Consum...
# 1   A Learning Approach for Energy Efficiency Opti...
# 2   A Temporal Motif Mining Approach to Unsupervis...
# 3   A context-aware method for building occupancy ...
# 4   A framework for knowledge discovery in massive...
# 5   A method for detecting abnormal electricity en...
# 6   A model-based fault detection and diagnostic m...
# 7   A new framework for the analysis of large scal...
# 8   A novel methodology for knowledge discovery th...
# 9   A novelty detection approach to identify the o...
# 10  A system-level fault detection and diagnosis s...
# 11  An Electric Energy Consumer Characterization F...
# 12  Analysis of Georeferenced Building Data for th...
# 13  Analysis of Similarity Measures in Times Serie...
# 14  Analysis of electricity bills using visual con...
# 15  Anomaly detection for visual analytics of powe...
# 16  Anomaly detection of building systems using en...
# 17  Application of Data Mining techniques for ener...
# 18  Application of clustering for the development ...
# 19  Assessment of potential energy saving using cl...
# 20  Automated daily pattern filtering of measured ...
# 21  Black-box models for fault detection and perfo...
# 22  Building energy and comfort management through...
# 23  Building energy information systems: user case...
# 24  Classification of Commerical Building Electric...
# 25  Classification, Filtering, and Identification ...
# 26  Cluster analysis of simulated energy use for L...
# 27  Clustering time-series energy data from smart ...
# 28  Clustering-Based Performance Optimization of t...
# 29  Computational intelligence based anomaly detec...
# ..                                                ...
# 70  Principal component analysis of electricity us...
# 71  Prioritizing and Visualizing Energy Management...
# 72  Real-time detection of anomalous power consump...
# 73  Reducing energy consumption by using self-orga...
# 74  Research Scoping Report: Visualizing Informati...
# 75          SMAS: A smart meter data analytics system
# 76  Sensor mining for user behavior profiling in i...
# 77  Sensor-fault detection, diagnosis and estimati...
# 78  Site-Level Energy Monitoring and Analysis usin...
# 79       SmartD: Smart Meter Data Analytics Dashboard
# 80  Softgreen: Towards energy management of green ...
# 81  Statistical Anomaly Detection in Mean and Vari...
# 82  Strip, bind, and search: a method for identify...
# 83  Support vector clustering of electrical load p...
# 84  Sustainable Operation and Management of Data C...
# 85  Targeted Efficiency: Using Customer Meter Data...
# 86  Temporal Knowledge Discovery in Big BAS Data f...
# 87  The energy dashboard: improving the visibility...
# 88  Towards Automatic Spatial Verification of Sens...
# 89  Towards an understanding of campus-scale power...
# 90  Typical load profiles in the smart grid contex...
# 91  Using intelligent clustering techniques to cla...
# 92  Using intelligent data analysis to detect abno...
# 93  Using principal component and cluster analysis...
# 94  Variability of electricity load patterns and i...
# 95  Visualizing Energy Information in Commercial B...
# 96  Visualizing building energy demand for buildin...
# 97  Visualizing frequent patterns in large multiva...
# 98  Wakame: Sense Making of Multi-dimensional Spat...
# 99  e2-Diagnoser: A System for Monitoring, Forecas...
#
#                                     Publication Title  \
# 0         IEEE Transactions on Industrial Informatics
# 1                Internet of Things. User-Centric IoT
# 2   Proceedings of the Twenty-Seventh AAAI Confere...
# 3                                Energy and Buildings
# 4                          Automation in Construction
# 5        Journal Of Computational Information Systems
# 6                                Energy and Buildings
# 7                                                 NaN
# 8                                Energy and Buildings
# 9   Proceedings of the 2015 International Joint Co...
# 10                               Energy and Buildings
# 11                 IEEE Transactions on Power Systems
# 12                            Proceedings of the IEEE
# 13                                           Energies
# 14                  Neural Computing and Applications
# 15                               Computers & Graphics
# 16  Power and Energy Society General Meeting, 2012...
# 17  Proceedings of eSim 2014 - IBPSA-Canada Confer...
# 18                   Advanced Engineering Informatics
# 19                               Energy and Buildings
# 20                         Automation in Construction
# 21         Journal of Building Performance Simulation
# 22         Journal of Building Performance Simulation
# 23                                  Energy Efficiency
# 24  Proceedings of ASME 2012 6th International Con...
# 25                 IEEE Transactions on Power Systems
# 26                               Energy and Buildings
# 27                                  Energy Efficiency
# 28             IEEE Transactions on Energy Conversion
# 29  Proceedings of the 5th International Symposium...
# ..                                                ...
# 70                               Energy and Buildings
# 71  Proceedings from 2011 Western Energy Policy Re...
# 72           Renewable and Sustainable Energy Reviews
# 73                                     Applied Energy
# 74                                                NaN
# 75  Proceedings of the 2015 IEEE 31st Internationa...
# 76  Advances in Distributed Agent-Based Retrieval ...
# 77                                     Applied Energy
# 78  Proceedings of the 2014 ASHRAE/IBPSA-USA Build...
# 79  Proceedings of the 5th International Conferenc...
# 80  Proceedings of the Fourth International Confer...
# 81  Proceedings of the 22nd International Conferen...
# 82  Proceedings of the 12th ACM/IEEE Int Conferenc...
# 83                 IEEE Transactions on Power Systems
# 84  Proceedings of the 15th ACM SIGKDD Internation...
# 85                                                NaN
# 86                               Energy and Buildings
# 87  Proceedings of the First ACM Workshop on Embed...
# 88  Proceedings of the 5th ACM Workshop on Embedde...
# 89  Proceedings of the Third ACM Workshop on Embed...
# 90  Proceedings of the Power and Energy Society Ge...
# 91                               Energy and Buildings
# 92                               Energy and Buildings
# 93                                     Applied Energy
# 94                                      Energy Policy
# 95                                                NaN
# 96                               Energy and Buildings
# 97  Proceedings of SPIE Conference on Visualizatio...
# 98  Proceedings of the International Conference on...
# 99  Data Mining Workshop (ICDMW), 2014 IEEE Intern...
#
#                                       Conference Name  \
# 0                                                 NaN
# 1                                                 NaN
# 2        Conference on Artificial Intelligence (AAAI)
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   International Joint Conference on Neural Netwo...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16      IEEE Power and Energy Society General Meeting
# 17                     IBPSA-Canada Conference (eSim)
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  ASME International Conference on Energy Sustai...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  International Symposium on Resilient Control S...
# ..                                                ...
# 70                                                NaN
# 71          Western Energy Policy Research Conference
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75  IEEE International Conference on Data Engineer...
# 76                                                NaN
# 77                                                NaN
# 78  IBPSA-USA Building Simulation Conference (SimB...
# 79  ACM International Conference on Future Energy ...
# 80  International Conference on Communication Syst...
# 81  International Conference on Pattern Recognitio...
# 82  ACM/IEEE Int Conference on Information Process...
# 83                                                NaN
# 84  ACM SIGKDD International Conference on Knowled...
# 85                                                NaN
# 86                                                NaN
# 87  ACM Workshop on Embedded Sensing Systems for E...
# 88  ACM Workshop on Embedded Sensing Systems for E...
# 89  ACM Workshop on Embedded Sensing Systems for E...
# 90      IEEE Power and Energy Society General Meeting
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97  SPIE Conference on Visualization and Data Anal...
# 98  International Conference on Advanced Visual In...
# 99  IEEE International Conference on Data Mining W...
#
#                                                Author        Item Type  \
# 0   De Silva, Daswin; Yu, Xinghuo; Alahakoon, Damm...   journalArticle
# 1      Mansur, Vitor; Carreira, Paulo; Arsenio, Artur      bookSection
# 2   Shao, Huijuan; Marwah, Manish; Ramakrishnan, N...  conferencePaper
# 3   Adamopoulou, Anna A.; Tryferidis, Athanasios M...   journalArticle
# 4                 Fan, Cheng; Xiao, Fu; Yan, Chengchu   journalArticle
# 5   Liu, Dandan; Chen, Qijun; Mori, Kazuyuki; Kida...   journalArticle
# 6                                  Li, Shun; Wen, Jin   journalArticle
# 7   Çakmak, Hüseyin Kemâl; Maa\s s, Heiko; Bach, F...             book
# 8   Yu, Zhun Jerry; Haghighat, Fariborz; Fung, Ben...   journalArticle
# 9   Fagiani, Marco; Squartini, Stefano; Severini, ...  conferencePaper
# 10              Wang, Shengwei; Zhou, Qiang; Xiao, Fu   journalArticle
# 11  Figueiredo, V; Rodrigues, F; Vale, Z; Gouveia,...   journalArticle
# 12                Schlueter, A.; Geyer, P.; Cisar, S.   journalArticle
# 13                 Iglesias, Félix; Kastner, Wolfgang   journalArticle
# 14  Morán, A; Fuertes, J J; Domínguez, M; Prada, M...   journalArticle
# 15  Janetzko, Halldór; Stoffel, Florian; Mittelstä...   journalArticle
# 16  Wrinch, Michael; El-Fouly, Tarek HM; Wong, Steven  conferencePaper
# 17                  Le Cam, M; Zmeureanu, R; Daoud, A  conferencePaper
# 18       Geyer, Philipp; Schlüter, Arno; Cisar, Sasha   journalArticle
# 19  Petcharat, Siriwarin; Chungpaibulpatana, Supac...   journalArticle
# 20     Miller, Clayton; Nagy, Zoltán; Schlueter, Arno   journalArticle
# 21  Jacob, Dirk; Dietz, Sebastian; Komhard, Susann...   journalArticle
# 22                          Dong, Bing; Lam, Khee Poh   journalArticle
# 23  Granderson, Jessica; Piette, Mary Ann; Ghatika...   journalArticle
# 24  Florita, Anthony R; Brackney, Larry J; Otanica...  conferencePaper
# 25  Verdu, S V; Garcia, M O; Senabre, C; Marin, A ...   journalArticle
# 26  Heidarinejad, Mohammad; Dahlhausen, Matthew; M...   journalArticle
# 27                   Lavin, Alexander; Klabjan, Diego   journalArticle
# 28                          Kusiak, Andrew; Song, Zhe   journalArticle
# 29     Linda, O; Wijayasekara, D; Manic, M; Rieger, C  conferencePaper
# ..                                                ...              ...
# 70  Lam, Joseph C; Wan, Kevin K W; Cheung, K L; Ya...   journalArticle
# 71  Duarte, Carlos; Acker, Brad; Grosshans, Ray; M...  conferencePaper
# 72          Chou, Jui-Sheng; Telaga, Abdi Suryadinata   journalArticle
# 73  Räsänen, Teemu; Ruuskanen, Juhani; Kolehmainen...   journalArticle
# 74                                      Lehrer, David           report
# 75               Liu, Xiufeng; Golab, L.; Ilyas, I.F.  conferencePaper
# 76  Augello, Agnese; Ortolani, Marco; Re, G Lo; Ga...   journalArticle
# 77                             Wang, Shengwei; Cui, J   journalArticle
# 78                             Georgescu, M; Mezic, I  conferencePaper
# 79  Jarrah Nezhad, Aylin; Wijaya, Tri Kurniawan; V...  conferencePaper
# 80  Thanayankizil, L V; Ghai, S K; Chakraborty, D;...  conferencePaper
# 81  Chen, Bei; Sinn, Mathieu; Ploennigs, Joern; Sc...  conferencePaper
# 82  Fontugne, Romain; Ortiz, Jorge; Tremblay, Nico...  conferencePaper
# 83                      Chicco, Gianfranco; Ilie, I S   journalArticle
# 84  Patnaik, Debprakash; Marwah, Manish; Sharma, R...  conferencePaper
# 85                                      Borgeson, Sam           thesis
# 86    Fan, Cheng; Xiao, Fu; Madsen, Henrik; Wang, Dan   journalArticle
# 87    Agarwal, Yuvraj; Weng, Thomas; Gupta, Rajesh K.  conferencePaper
# 88  Hong, Dezhi; Ortiz, Jorge; Whitehouse, Kamin; ...  conferencePaper
# 89  Bellala, Gowtham; Marwah, Manish; Arlitt, Mart...  conferencePaper
# 90  Ramos, Sérgio; Duarte, JMM; Soares, João; Vale...  conferencePaper
# 91  Santamouris, M; Mihalakakou, G; Patargias, P; ...   journalArticle
# 92                                       Seem, John E   journalArticle
# 93  Gaitani, N; Lehmann, C; Santamouris, M; Mihala...   journalArticle
# 94  Jang, Dongsik; Eom, Jiyong; Jae Park, Min; Jeu...   journalArticle
# 95                     Lehrer, David; Vasudev, Janani           report
# 96  Yarbrough, I.; Sun, Q.; Reeves, D. C.; Hackman...   journalArticle
# 97  Hao, M.; Marwah, M.; Janetzko, H.; Sharma, R.;...  conferencePaper
# 98                Forlines, Clifton; Wittenburg, Kent  conferencePaper
# 99  Ploennigs, Joern; Chen, Bei; Palmes, Paulito; ...  conferencePaper
#
#     Publication Year                    Sector      AppTagGeneral  \
# 0               2011    Electrical Engineering         SmartMeter
# 1               2015          Computer Science         Operations
# 2               2013          Computer Science         SmartMeter
# 3               2015  Building Energy Analysis         Operations
# 4               2015  Building Energy Analysis   AnomalyDetection
# 5               2010          Computer Science   AnomalyDetection
# 6               2014  Building Energy Analysis   AnomalyDetection
# 7               2014    Electrical Engineering         SmartMeter
# 8               2012  Building Energy Analysis   AnomalyDetection
# 9               2015          Computer Science         SmartMeter
# 10              2010  Building Energy Analysis   AnomalyDetection
# 11              2005    Electrical Engineering         SmartMeter
# 12              2016  Building Energy Analysis  PortfolioAnalysis
# 13              2013    Electrical Engineering         SmartMeter
# 14              2013          Computer Science  PortfolioAnalysis
# 15              2013          Computer Science   AnomalyDetection
# 16              2012    Electrical Engineering   AnomalyDetection
# 17              2014       Building Simulation   AnomalyDetection
# 18              2016  Building Energy Analysis  PortfolioAnalysis
# 19              2012  Building Energy Analysis  PortfolioAnalysis
# 20              2015  Building Energy Analysis  PortfolioAnalysis
# 21              2010       Building Simulation   AnomalyDetection
# 22              2011       Building Simulation         Operations
# 23              2010  Building Energy Analysis  PortfolioAnalysis
# 24              2012       Building Simulation         SmartMeter
# 25              2006    Electrical Engineering         SmartMeter
# 26              2014  Building Energy Analysis  PortfolioAnalysis
# 27              2014  Building Energy Analysis         SmartMeter
# 28              2008    Electrical Engineering         Operations
# 29              2012    Electrical Engineering   AnomalyDetection
# ..               ...                       ...                ...
# 70              2008  Building Energy Analysis  PortfolioAnalysis
# 71              2011  Building Energy Analysis         Operations
# 72              2014  Building Energy Analysis   AnomalyDetection
# 73              2008          Computer Science         SmartMeter
# 74              2009  Building Energy Analysis  PortfolioAnalysis
# 75              2015          Computer Science         SmartMeter
# 76              2011          Computer Science         Operations
# 77              2005  Building Energy Analysis   AnomalyDetection
# 78              2014       Building Simulation  PortfolioAnalysis
# 79              2014          Computer Science         SmartMeter
# 80              2012    Electrical Engineering         Operations
# 81              2014    Electrical Engineering   AnomalyDetection
# 82              2013          Computer Science   AnomalyDetection
# 83              2009    Electrical Engineering         SmartMeter
# 84              2009          Computer Science         Operations
# 85              2013  Building Energy Analysis         SmartMeter
# 86              2015  Building Energy Analysis         Operations
# 87              2009          Computer Science  PortfolioAnalysis
# 88              2013          Computer Science         Operations
# 89              2011          Computer Science  PortfolioAnalysis
# 90              2012    Electrical Engineering         SmartMeter
# 91              2007  Building Energy Analysis  PortfolioAnalysis
# 92              2006  Building Energy Analysis   AnomalyDetection
# 93              2010  Building Energy Analysis  PortfolioAnalysis
# 94              2016  Building Energy Analysis         SmartMeter
# 95              2011  Building Energy Analysis  PortfolioAnalysis
# 96              2015  Building Energy Analysis  PortfolioAnalysis
# 97              2011          Computer Science         Operations
# 98              2010          Computer Science   AnomalyDetection
# 99              2014    Electrical Engineering  PortfolioAnalysis
#
#       TechniqueTagGen                                   TechniqueTagSpec  \
# 0     Motif Detection  Incremental Summarization and Pattern Char. (I...
# 1          Clustering                                            K-Means
# 2     Motif Detection  Dirichlet Process Gaussian Mixture Models (DPGMM)
# 3     Rule Extraction                                      Markov Models
# 4   Novelty Detection                        Data Assocation Rules (DAR)
# 5   Novelty Detection           Classification and Regression Tree(CART)
# 6   Novelty Detection                 Principal Component Analysis (PCA)
# 7    Visual Analytics                                Multiple Techniques
# 8     Rule Extraction                        Data Assocation Rules (DAR)
# 9   Novelty Detection                                      Markov Models
# 10  Novelty Detection                 Principal Component Analysis (PCA)
# 11         Clustering                                            K-Means
# 12         Clustering                                   Fuzzy Clustering
# 13         Clustering                                Multiple Techniques
# 14   Visual Analytics                                   Pattern Analysis
# 15   Visual Analytics                                   Pattern Analysis
# 16  Novelty Detection                                  Fourier Transform
# 17  Novelty Detection                 Principal Component Analysis (PCA)
# 18         Clustering                                Multiple Techniques
# 19         Clustering                            Maximum Likelihood (ML)
# 20    Motif Detection             Symbolic Aggregate Approximation (SAX)
# 21         Clustering                            Hierarchical Clustering
# 22    Motif Detection                                      Markov Models
# 23   Visual Analytics                   Energy Information Systems (EIS)
# 24         Clustering                                           Bayesian
# 25         Clustering                         Self-Organizing Maps (SOM)
# 26         Clustering                                            K-Means
# 27         Clustering                                            K-Means
# 28         Clustering                                Multiple Techniques
# 29  Novelty Detection                                   Nearest Neighbor
# ..                ...                                                ...
# 70  Novelty Detection                 Principal Component Analysis (PCA)
# 71   Visual Analytics                   Energy Information Systems (EIS)
# 72         Clustering                                            K-Means
# 73         Clustering                         Self-Organizing Maps (SOM)
# 74   Visual Analytics                   Energy Information Systems (EIS)
# 75   Visual Analytics                                   Pattern Analysis
# 76         Clustering                                Multiple Techniques
# 77  Novelty Detection                 Principal Component Analysis (PCA)
# 78   Visual Analytics                                   Pattern Analysis
# 79   Visual Analytics                                   Pattern Analysis
# 80    Motif Detection                            Maximum Likelihood (ML)
# 81  Novelty Detection                  Generalized Additive Models (GAM)
# 82  Novelty Detection                                Multiple Techniques
# 83         Clustering                      Support Vector Machines (SVM)
# 84    Motif Detection             Symbolic Aggregate Approximation (SAX)
# 85         Clustering                                Multiple Techniques
# 86    Rule Extraction                        Data Assocation Rules (DAR)
# 87   Visual Analytics                   Energy Information Systems (EIS)
# 88         Clustering                 Empirical Mode Decomposition (EMC)
# 89  Novelty Detection                                      Markov Models
# 90         Clustering                                Multiple Techniques
# 91         Clustering                                   Fuzzy Clustering
# 92  Novelty Detection     Generalized Extreme Studentized Deviate (GESD)
# 93         Clustering                                Multiple Techniques
# 94         Clustering                                            K-Means
# 95   Visual Analytics                   Energy Information Systems (EIS)
# 96   Visual Analytics                   Energy Information Systems (EIS)
# 97   Visual Analytics                                   Pattern Analysis
# 98   Visual Analytics                                   Pattern Analysis
# 99  Novelty Detection                  Generalized Additive Models (GAM)
#
#          AppTagSpecific                                              title  \
# 0        Load Profiling  A Data Mining Framework for Electricity Consum...
# 1   Occupancy Detection  A Learning Approach for Energy Efficiency Opti...
# 2        Disaggregation  A Temporal Motif Mining Approach to Unsupervis...
# 3   Occupancy Detection  A context-aware method for building occupancy ...
# 4        Whole Building  A framework for knowledge discovery in massive...
# 5        Whole Building  A method for detecting abnormal electricity en...
# 6             Subsystem  A model-based fault detection and diagnostic m...
# 7       Customer Class.  A new framework for the analysis of large scal...
# 8             Component  A novel methodology for knowledge discovery th...
# 9       Customer Class.  A novelty detection approach to identify the o...
# 10            Subsystem  A system-level fault detection and diagnosis s...
# 11      Customer Class.  An Electric Energy Consumer Characterization F...
# 12            Targeting  Analysis of Georeferenced Building Data for th...
# 13       Load Profiling  Analysis of Similarity Measures in Times Serie...
# 14     Characterization  Analysis of electricity bills using visual con...
# 15       Whole Building  Anomaly detection for visual analytics of powe...
# 16       Whole Building  Anomaly detection of building systems using en...
# 17            Subsystem  Application of Data Mining techniques for ener...
# 18            Targeting  Application of clustering for the development ...
# 19            Targeting  Assessment of potential energy saving using cl...
# 20     Characterization  Automated daily pattern filtering of measured ...
# 21       Whole Building  Black-box models for fault detection and perfo...
# 22  Occupancy Detection  Building energy and comfort management through...
# 23     Characterization  Building energy information systems: user case...
# 24      Customer Class.  Classification of Commerical Building Electric...
# 25      Customer Class.  Classification, Filtering, and Identification ...
# 26          Classifying  Cluster analysis of simulated energy use for L...
# 27       Load Profiling  Clustering time-series energy data from smart ...
# 28             Controls  Clustering-Based Performance Optimization of t...
# 29            Subsystem  Computational intelligence based anomaly detec...
# ..                  ...                                                ...
# 70     Characterization  Principal component analysis of electricity us...
# 71    Energy Management  Prioritizing and Visualizing Energy Management...
# 72       Whole Building  Real-time detection of anomalous power consump...
# 73      Customer Class.  Reducing energy consumption by using self-orga...
# 74     Characterization  Research Scoping Report: Visualizing Informati...
# 75      Customer Class.          SMAS: A smart meter data analytics system
# 76  Occupancy Detection  Sensor mining for user behavior profiling in i...
# 77            Component  Sensor-fault detection, diagnosis and estimati...
# 78     Characterization  Site-Level Energy Monitoring and Analysis usin...
# 79       Load Profiling       SmartD: Smart Meter Data Analytics Dashboard
# 80  Occupancy Detection  Softgreen: Towards energy management of green ...
# 81       Whole Building  Statistical Anomaly Detection in Mean and Vari...
# 82       Whole Building  Strip, bind, and search: a method for identify...
# 83       Load Profiling  Support vector clustering of electrical load p...
# 84             Controls  Sustainable Operation and Management of Data C...
# 85      Customer Class.  Targeted Efficiency: Using Customer Meter Data...
# 86    Energy Management  Temporal Knowledge Discovery in Big BAS Data f...
# 87     Characterization  The energy dashboard: improving the visibility...
# 88             Controls  Towards Automatic Spatial Verification of Sens...
# 89            Targeting  Towards an understanding of campus-scale power...
# 90       Load Profiling                                                NaN
# 91          Classifying  Using intelligent clustering techniques to cla...
# 92       Whole Building  Using intelligent data analysis to detect abno...
# 93            Targeting  Using principal component and cluster analysis...
# 94      Customer Class.  Variability of electricity load patterns and i...
# 95     Characterization  Visualizing Energy Information in Commercial B...
# 96     Characterization  Visualizing building energy demand for buildin...
# 97             Controls  Visualizing frequent patterns in large multiva...
# 98            Subsystem  Wakame: Sense Making of Multi-dimensional Spat...
# 99          Classifying  e2-Diagnoser: A System for Monitoring, Forecas...
#
#                                 ID
# 0               de_silva_data_2011
# 1             mansur_learning_2015
# 2               shao_temporal_2013
# 3   adamopoulou_context-aware_2015
# 4               fan_framework_2015
# 5                  liu_method_2010
# 6              li_model-based_2014
# 7                  cakmak_new_2014
# 8                    yu_novel_2012
# 9             fagiani_novelty_2015
# 10          wang_system-level_2010
# 11        figueiredo_electric_2005
# 12         schlueter_analysis_2016
# 13          iglesias_analysis_2013
# 14             moran_analysis_2013
# 15           janetzko_anomaly_2013
# 16             wrinch_anomaly_2012
# 17         le_cam_application_2014
# 18          geyer_application_2016
# 19       petcharat_assessment_2012
# 20           miller_automated_2015
# 21            jacob_black-box_2010
# 22              dong_building_2011
# 23        granderson_building_2010
# 24     florita_classification_2012
# 25       verdu_classification_2006
# 26       heidarinejad_cluster_2014
# 27           lavin_clustering_2014
# 28    kusiak_clustering-based_2008
# 29        linda_computational_2012
# ..                             ...
# 70              lam_principal_2008
# 71        duarte_prioritizing_2011
# 72             chou_real-time_2014
# 73           rasanen_reducing_2008
# 74            lehrer_research_2009
# 75                  liu_smas:_2015
# 76             augello_sensor_2011
# 77          wang_sensor-fault_2005
# 78       georgescu_site-level_2014
# 79      jarrah_nezhad_smartd:_2014
# 80   thanayankizil_softgreen:_2012
# 81           chen_statistical_2014
# 82             fontugne_strip_2013
# 83             chicco_support_2009
# 84        patnaik_sustainable_2009
# 85          borgeson_targeted_2013
# 86               fan_temporal_2015
# 87             agarwal_energy_2009
# 88               hong_towards_2013
# 89            bellala_towards_2011
# 90                             NaN
# 91          santamouris_using_2007
# 92                 seem_using_2006
# 93              gaitani_using_2010
# 94           jang_variability_2016
# 95         lehrer_visualizing_2011
# 96      yarbrough_visualizing_2015
# 97            hao_visualizing_2011
# 98           forlines_wakame:_2010
# 99    ploennigs_e2-diagnoser:_2014
#
# [100 rows x 13 columns]

# %%
mergeddata.to_csv('WholeReferenceList.csv')

# %% [markdown]
# Now we go through and label each review with journal name or journal/conference category

# %%
mergeddata_labelled = pd.read_csv("WholeReferenceList_PublicationTypeTagged.csv")

# %%
mergeddata_labelled
# Out:
#     Unnamed: 0                                              Title  \
# 0           78  Strip, bind, and search: a method for identify...
# 1           80  Sustainable Operation and Management of Data C...
# 2           43  Exploiting Generalized Additive Models for Dia...
# 3           84  Towards Automatic Spatial Verification of Sens...
# 4           83  The energy dashboard: improving the visibility...
# 5           85  Towards an understanding of campus-scale power...
# 6           69  Reducing energy consumption by using self-orga...
# 7           73  Sensor-fault detection, diagnosis and estimati...
# 8           89  Using principal component and cluster analysis...
# 9           22  Classification of Commerical Building Electric...
# 10           4  A framework for knowledge discovery in massive...
# 11          18  Automated daily pattern filtering of measured ...
# 12           3  A context-aware method for building occupancy ...
# 13           6  A model-based fault detection and diagnostic m...
# 14           8  A novel methodology for knowledge discovery th...
# 15          10  A system-level fault detection and diagnosis s...
# 16          17  Assessment of potential energy saving using cl...
# 17          24  Cluster analysis of simulated energy use for L...
# 18          30  Data association mining for identifying lighti...
# 19          32  Data mining in building automation system for ...
# 20          47  Fault diagnosis for sensors in air handling un...
# 21          52  Identifying energy consumption patterns in the...
# 22          61  Occupancy schedules learning process through a...
# 23          63  Pattern recognition algorithm for determining ...
# 24          66  Principal component analysis of electricity us...
# 25          82  Temporal Knowledge Discovery in Big BAS Data f...
# 26          87  Using intelligent clustering techniques to cla...
# 27          88  Using intelligent data analysis to detect abno...
# 28          91  Visualizing building energy demand for buildin...
# 29          21  Building energy information systems: user case...
# ..         ...                                                ...
# 65          65  Prediction of Chiller Power Consumption Using ...
# 66          68  Real-time detection of anomalous power consump...
# 67          29  Data and Interfaces for Advanced Building Oper...
# 68          70  Research Scoping Report: Visualizing Informati...
# 69          81  Targeted Efficiency: Using Customer Meter Data...
# 70          90  Visualizing Energy Information in Commercial B...
# 71          57  Low-voltage electricity customer profiling bas...
# 72           9  A novelty detection approach to identify the o...
# 73          54  Improving load forecast accuracy by clustering...
# 74          75       SmartD: Smart Meter Data Analytics Dashboard
# 75          93  Wakame: Sense Making of Multi-dimensional Spat...
# 76           2  A Temporal Motif Mining Approach to Unsupervis...
# 77          72  Sensor mining for user behavior profiling in i...
# 78          28  Data Mining for Modeling Chiller Systems in Da...
# 79          14  Anomaly detection for visual analytics of powe...
# 80          53  Improving energy efficiency in buildings using...
# 81           1  A Learning Approach for Energy Efficiency Opti...
# 82          13  Analysis of electricity bills using visual con...
# 83          49  Finding the Different Patterns in Buildings Da...
# 84          48  Feature-based clustering for electricity use t...
# 85          77  Statistical Anomaly Detection in Mean and Vari...
# 86          27  Computational intelligence based anomaly detec...
# 87          76  Softgreen: Towards energy management of green ...
# 88          37  Energy Consumption Improvement Through a Visua...
# 89          42  Evaluation of the performance of clustering al...
# 90           5  A method for detecting abnormal electricity en...
# 91          56  Learning decision rules for energy efficient b...
# 92           7  A new framework for the analysis of large scal...
# 93          92  Visualizing frequent patterns in large multiva...
# 94          33  Discovering unexpected information using a bui...
#
#                                     Publication Title  \
# 0   Proceedings of the 12th ACM/IEEE Int Conferenc...
# 1   Proceedings of the 15th ACM SIGKDD Internation...
# 2   Proceedings of the 5th ACM Workshop On Embedde...
# 3   Proceedings of the 5th ACM Workshop on Embedde...
# 4   Proceedings of the First ACM Workshop on Embed...
# 5   Proceedings of the Third ACM Workshop on Embed...
# 6                                      Applied Energy
# 7                                      Applied Energy
# 8                                      Applied Energy
# 9   Proceedings of ASME 2012 6th International Con...
# 10                         Automation in Construction
# 11                         Automation in Construction
# 12                               Energy and Buildings
# 13                               Energy and Buildings
# 14                               Energy and Buildings
# 15                               Energy and Buildings
# 16                               Energy and Buildings
# 17                               Energy and Buildings
# 18                               Energy and Buildings
# 19                               Energy and Buildings
# 20                               Energy and Buildings
# 21                               Energy and Buildings
# 22                               Energy and Buildings
# 23                               Energy and Buildings
# 24                               Energy and Buildings
# 25                               Energy and Buildings
# 26                               Energy and Buildings
# 27                               Energy and Buildings
# 28                               Energy and Buildings
# 29                                  Energy Efficiency
# ..                                                ...
# 65  Proceedings of the 8th International Conferenc...
# 66           Renewable and Sustainable Energy Reviews
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71  Proceedings of the 2009 International Database...
# 72  Proceedings of the 2015 International Joint Co...
# 73  Proceedings of the 2015 International Joint Co...
# 74  Proceedings of the 5th International Conferenc...
# 75  Proceedings of the International Conference on...
# 76  Proceedings of the Twenty-Seventh AAAI Confere...
# 77  Advances in Distributed Agent-Based Retrieval ...
# 78           Advances in Intelligent Data Analysis IX
# 79                               Computers & Graphics
# 80  Intelligent Data Engineering and Automated Lea...
# 81               Internet of Things. User-Centric IoT
# 82                  Neural Computing and Applications
# 83  2015 13th International Conference on Frontier...
# 84  Adaptive and Natural Computing Algorithms: 9th...
# 85  Proceedings of the 22nd International Conferen...
# 86  Proceedings of the 5th International Symposium...
# 87  Proceedings of the Fourth International Confer...
# 88  Energy Efficiency - A Bridge to Low Carbon Eco...
# 89  Engineering Applications of Artificial Intelli...
# 90       Journal Of Computational Information Systems
# 91                         Journal of Process Control
# 92                                                NaN
# 93  Proceedings of SPIE Conference on Visualizatio...
# 94  Proceedings of the IS&T/SPIE 2013 Conference o...
#
#                                       Conference Name  \
# 0   ACM/IEEE Int Conference on Information Process...
# 1   ACM SIGKDD International Conference on Knowled...
# 2   ACM Workshop on Embedded Sensing Systems for E...
# 3   ACM Workshop on Embedded Sensing Systems for E...
# 4   ACM Workshop on Embedded Sensing Systems for E...
# 5   ACM Workshop on Embedded Sensing Systems for E...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   ASME International Conference on Energy Sustai...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 65  International Conference on Indoor Air Quality...
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71  International Database Engineering & Applicati...
# 72  International Joint Conference on Neural Netwo...
# 73  International Joint Conference on Neural Netwo...
# 74  ACM International Conference on Future Energy ...
# 75  International Conference on Advanced Visual In...
# 76       Conference on Artificial Intelligence (AAAI)
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83  2015 13th International Conference on Frontier...
# 84  International Conference on Adaptive and Natur...
# 85  International Conference on Pattern Recognitio...
# 86  International Symposium on Resilient Control S...
# 87  International Conference on Communication Syst...
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93  SPIE Conference on Visualization and Data Anal...
# 94         IS&T/SPIE Conference on Electronic Imaging
#
#                          PublicationType  \
# 0                         ACM Conference
# 1                         ACM Conference
# 2                         ACM Conference
# 3                         ACM Conference
# 4                         ACM Conference
# 5                         ACM Conference
# 6               Applied Energy (Journal)
# 7               Applied Energy (Journal)
# 8               Applied Energy (Journal)
# 9            Other Building Sci. Journal
# 10  Automation in Construction (Journal)
# 11  Automation in Construction (Journal)
# 12        Energy and Buildings (Journal)
# 13        Energy and Buildings (Journal)
# 14        Energy and Buildings (Journal)
# 15        Energy and Buildings (Journal)
# 16        Energy and Buildings (Journal)
# 17        Energy and Buildings (Journal)
# 18        Energy and Buildings (Journal)
# 19        Energy and Buildings (Journal)
# 20        Energy and Buildings (Journal)
# 21        Energy and Buildings (Journal)
# 22        Energy and Buildings (Journal)
# 23        Energy and Buildings (Journal)
# 24        Energy and Buildings (Journal)
# 25        Energy and Buildings (Journal)
# 26        Energy and Buildings (Journal)
# 27        Energy and Buildings (Journal)
# 28        Energy and Buildings (Journal)
# 29           Energy Efficiency (Journal)
# ..                                   ...
# 65           Other Building Sci. Journal
# 66           Other Building Sci. Journal
# 67           Other Building Sci. Journal
# 68           Other Building Sci. Journal
# 69           Other Building Sci. Journal
# 70           Other Building Sci. Journal
# 71                Other Comp. Sci. Conf.
# 72                Other Comp. Sci. Conf.
# 73                Other Comp. Sci. Conf.
# 74                Other Comp. Sci. Conf.
# 75                Other Comp. Sci. Conf.
# 76                Other Comp. Sci. Conf.
# 77              Other Comp. Sci. Journal
# 78              Other Comp. Sci. Journal
# 79              Other Comp. Sci. Journal
# 80              Other Comp. Sci. Journal
# 81              Other Comp. Sci. Journal
# 82              Other Comp. Sci. Journal
# 83         Other Elec. Engineering Conf.
# 84         Other Elec. Engineering Conf.
# 85         Other Elec. Engineering Conf.
# 86         Other Elec. Engineering Conf.
# 87         Other Elec. Engineering Conf.
# 88       Other Elec. Engineering Journal
# 89       Other Elec. Engineering Journal
# 90       Other Elec. Engineering Journal
# 91       Other Elec. Engineering Journal
# 92       Other Elec. Engineering Journal
# 93                       SPIE Conference
# 94                       SPIE Conference
#
#                                                Author        Item Type  \
# 0   Fontugne, Romain; Ortiz, Jorge; Tremblay, Nico...  conferencePaper
# 1   Patnaik, Debprakash; Marwah, Manish; Sharma, R...  conferencePaper
# 2   Ploennigs, Joern; Chen, Bei; Schumann, Anika; ...  conferencePaper
# 3   Hong, Dezhi; Ortiz, Jorge; Whitehouse, Kamin; ...  conferencePaper
# 4     Agarwal, Yuvraj; Weng, Thomas; Gupta, Rajesh K.  conferencePaper
# 5   Bellala, Gowtham; Marwah, Manish; Arlitt, Mart...  conferencePaper
# 6   R�_s�_nen, Teemu; Ruuskanen, Juhani; Kolehmain...   journalArticle
# 7                              Wang, Shengwei; Cui, J   journalArticle
# 8   Gaitani, N; Lehmann, C; Santamouris, M; Mihala...   journalArticle
# 9   Florita, Anthony R; Brackney, Larry J; Otanica...  conferencePaper
# 10                Fan, Cheng; Xiao, Fu; Yan, Chengchu   journalArticle
# 11    Miller, Clayton; Nagy, Zolt��n; Schlueter, Arno   journalArticle
# 12  Adamopoulou, Anna A.; Tryferidis, Athanasios M...   journalArticle
# 13                                 Li, Shun; Wen, Jin   journalArticle
# 14  Yu, Zhun Jerry; Haghighat, Fariborz; Fung, Ben...   journalArticle
# 15              Wang, Shengwei; Zhou, Qiang; Xiao, Fu   journalArticle
# 16  Petcharat, Siriwarin; Chungpaibulpatana, Supac...   journalArticle
# 17  Heidarinejad, Mohammad; Dahlhausen, Matthew; M...   journalArticle
# 18       Cabrera, David F Motta; Zareipour, Hamidreza   journalArticle
# 19                               Xiao, Fu; Fan, Cheng   journalArticle
# 20             Zhu, Yonghua; Jin, Xinqiao; Du, Zhimin   journalArticle
# 21  Pieri, Stella Panayiota; IoannisTzouvadakis; S...   journalArticle
# 22                     D�۪Oca, Simona; Hong, Tianzhen   journalArticle
# 23                                       Seem, John E   journalArticle
# 24  Lam, Joseph C; Wan, Kevin K W; Cheung, K L; Ya...   journalArticle
# 25    Fan, Cheng; Xiao, Fu; Madsen, Henrik; Wang, Dan   journalArticle
# 26  Santamouris, M; Mihalakakou, G; Patargias, P; ...   journalArticle
# 27                                       Seem, John E   journalArticle
# 28  Yarbrough, I.; Sun, Q.; Reeves, D. C.; Hackman...   journalArticle
# 29  Granderson, Jessica; Piette, Mary Ann; Ghatika...   journalArticle
# ..                                                ...              ...
# 65               Fan, Cheng; Xiao, Fu; Shengwei, Wang  conferencePaper
# 66          Chou, Jui-Sheng; Telaga, Abdi Suryadinata   journalArticle
# 67  Gayeski, Nicholas; Kleindienst, Sian; Gagne, J...           report
# 68                                      Lehrer, David           report
# 69                                      Borgeson, Sam           thesis
# 70                     Lehrer, David; Vasudev, Janani           report
# 71  Gullo, Francesco; Ponti, Giovanni; Tagarelli, ...  conferencePaper
# 72  Fagiani, Marco; Squartini, Stefano; Severini, ...  conferencePaper
# 73  Shahzadeh, Abbas; Khosravi, Abbas; Nahavandi, ...  conferencePaper
# 74  Jarrah Nezhad, Aylin; Wijaya, Tri Kurniawan; V...  conferencePaper
# 75                Forlines, Clifton; Wittenburg, Kent  conferencePaper
# 76  Shao, Huijuan; Marwah, Manish; Ramakrishnan, N...  conferencePaper
# 77  Augello, Agnese; Ortolani, Marco; Re, G Lo; Ga...   journalArticle
# 78  Patnaik, Debprakash; Marwah, Manish; Sharma, R...      bookSection
# 79  Janetzko, Halld�_r; Stoffel, Florian; Mittelst...   journalArticle
# 80  Sedano, Javier; Villar, Jos̩ Ram�_n; Curiel, L...      bookSection
# 81     Mansur, Vitor; Carreira, Paulo; Arsenio, Artur      bookSection
# 82  Mor��n, A; Fuertes, J J; Dom�_nguez, M; Prada,...   journalArticle
# 83                              Habib, U.; Zucker, G.  conferencePaper
# 84               R�_s�_nen, Teemu; Kolehmainen, Mikko  conferencePaper
# 85  Chen, Bei; Sinn, Mathieu; Ploennigs, Joern; Sc...  conferencePaper
# 86     Linda, O; Wijayasekara, D; Manic, M; Rieger, C  conferencePaper
# 87  Thanayankizil, L V; Ghai, S K; Chakraborty, D;...  conferencePaper
# 88    Lange, Benoit; Rodriguez, Nancy; Puech, William      bookSection
# 89  Panapakidis, Ioannis; Alexiadis, Minas; Papagi...   journalArticle
# 90  Liu, Dandan; Chen, Qijun; Mori, Kazuyuki; Kida...   journalArticle
# 91  Domahidi, Alexander; Ullmann, Fabian; Morari, ...   journalArticle
# 92  ��akmak, H�_seyin Kem̢l; Maa\s s, Heiko; Bach,...             book
# 93  Hao, M.; Marwah, M.; Janetzko, H.; Sharma, R.;...  conferencePaper
# 94       Lange, B; Rodriguez, N; Puech, W; Vasques, X  conferencePaper
#
#     Publication Year                    Sector      AppTagGeneral  \
# 0               2013          Computer Science   AnomalyDetection
# 1               2009          Computer Science         Operations
# 2               2013    Electrical Engineering   AnomalyDetection
# 3               2013          Computer Science         Operations
# 4               2009          Computer Science  PortfolioAnalysis
# 5               2011          Computer Science  PortfolioAnalysis
# 6               2008          Computer Science         SmartMeter
# 7               2005  Building Energy Analysis   AnomalyDetection
# 8               2010  Building Energy Analysis  PortfolioAnalysis
# 9               2012       Building Simulation         SmartMeter
# 10              2015  Building Energy Analysis   AnomalyDetection
# 11              2015  Building Energy Analysis  PortfolioAnalysis
# 12              2015  Building Energy Analysis         Operations
# 13              2014  Building Energy Analysis   AnomalyDetection
# 14              2012  Building Energy Analysis   AnomalyDetection
# 15              2010  Building Energy Analysis   AnomalyDetection
# 16              2012  Building Energy Analysis  PortfolioAnalysis
# 17              2014  Building Energy Analysis  PortfolioAnalysis
# 18              2013  Building Energy Analysis  PortfolioAnalysis
# 19              2014  Building Energy Analysis         Operations
# 20              2012  Building Energy Analysis   AnomalyDetection
# 21              2015  Building Energy Analysis  PortfolioAnalysis
# 22              2015  Building Energy Analysis         Operations
# 23              2005  Building Energy Analysis  PortfolioAnalysis
# 24              2008  Building Energy Analysis  PortfolioAnalysis
# 25              2015  Building Energy Analysis         Operations
# 26              2007  Building Energy Analysis  PortfolioAnalysis
# 27              2006  Building Energy Analysis   AnomalyDetection
# 28              2015  Building Energy Analysis  PortfolioAnalysis
# 29              2010  Building Energy Analysis  PortfolioAnalysis
# ..               ...                       ...                ...
# 65              2013  Building Energy Analysis         Operations
# 66              2014  Building Energy Analysis   AnomalyDetection
# 67              2015  Building Energy Analysis         Operations
# 68              2009  Building Energy Analysis  PortfolioAnalysis
# 69              2013  Building Energy Analysis         SmartMeter
# 70              2011  Building Energy Analysis  PortfolioAnalysis
# 71              2009          Computer Science         SmartMeter
# 72              2015          Computer Science         SmartMeter
# 73              2015          Computer Science         SmartMeter
# 74              2014          Computer Science         SmartMeter
# 75              2010          Computer Science   AnomalyDetection
# 76              2013          Computer Science         SmartMeter
# 77              2011          Computer Science         Operations
# 78              2010          Computer Science         Operations
# 79              2013          Computer Science   AnomalyDetection
# 80              2009          Computer Science  PortfolioAnalysis
# 81              2015          Computer Science         Operations
# 82              2013          Computer Science  PortfolioAnalysis
# 83              2015    Electrical Engineering         Operations
# 84              2009    Electrical Engineering         SmartMeter
# 85              2014    Electrical Engineering   AnomalyDetection
# 86              2012    Electrical Engineering   AnomalyDetection
# 87              2012    Electrical Engineering         Operations
# 88              2012    Electrical Engineering         Operations
# 89              2015    Electrical Engineering         SmartMeter
# 90              2010          Computer Science   AnomalyDetection
# 91              2014    Electrical Engineering         Operations
# 92              2014    Electrical Engineering         SmartMeter
# 93              2011          Computer Science         Operations
# 94              2013    Electrical Engineering         Operations
#
#       TechniqueTagGen                                   TechniqueTagSpec  \
# 0   Novelty Detection                                Multiple Techniques
# 1     Motif Detection             Symbolic Aggregate Approximation (SAX)
# 2   Novelty Detection                  Generalized Additive Models (GAM)
# 3          Clustering                 Empirical Mode Decomposition (EMC)
# 4    Visual Analytics                   Energy Information Systems (EIS)
# 5   Novelty Detection                                      Markov Models
# 6          Clustering                         Self-Organizing Maps (SOM)
# 7   Novelty Detection                 Principal Component Analysis (PCA)
# 8          Clustering                                Multiple Techniques
# 9          Clustering                                           Bayesian
# 10  Novelty Detection                        Data Assocation Rules (DAR)
# 11    Motif Detection             Symbolic Aggregate Approximation (SAX)
# 12    Rule Extraction                                      Markov Models
# 13  Novelty Detection                 Principal Component Analysis (PCA)
# 14    Rule Extraction                        Data Assocation Rules (DAR)
# 15  Novelty Detection                 Principal Component Analysis (PCA)
# 16         Clustering                            Maximum Likelihood (ML)
# 17         Clustering                                            K-Means
# 18    Rule Extraction                        Data Assocation Rules (DAR)
# 19    Rule Extraction                        Data Assocation Rules (DAR)
# 20  Novelty Detection                                           Wavelets
# 21         Clustering                                Multiple Techniques
# 22    Rule Extraction                                Multiple Techniques
# 23         Clustering                            Hierarchical Clustering
# 24  Novelty Detection                 Principal Component Analysis (PCA)
# 25    Rule Extraction                        Data Assocation Rules (DAR)
# 26         Clustering                                   Fuzzy Clustering
# 27  Novelty Detection     Generalized Extreme Studentized Deviate (GESD)
# 28   Visual Analytics                   Energy Information Systems (EIS)
# 29   Visual Analytics                   Energy Information Systems (EIS)
# ..                ...                                                ...
# 65         Clustering                                            K-Means
# 66         Clustering                                            K-Means
# 67   Visual Analytics                   Energy Information Systems (EIS)
# 68   Visual Analytics                   Energy Information Systems (EIS)
# 69         Clustering                                Multiple Techniques
# 70   Visual Analytics                   Energy Information Systems (EIS)
# 71         Clustering                                Multiple Techniques
# 72  Novelty Detection                                      Markov Models
# 73         Clustering                                            K-Means
# 74   Visual Analytics                                   Pattern Analysis
# 75   Visual Analytics                                   Pattern Analysis
# 76    Motif Detection  Dirichlet Process Gaussian Mixture Models (DPGMM)
# 77         Clustering                                Multiple Techniques
# 78    Motif Detection             Symbolic Aggregate Approximation (SAX)
# 79   Visual Analytics                                   Pattern Analysis
# 80         Clustering                            Maximum Likelihood (ML)
# 81         Clustering                                            K-Means
# 82   Visual Analytics                                   Pattern Analysis
# 83    Motif Detection             Symbolic Aggregate Approximation (SAX)
# 84         Clustering                                Multiple Techniques
# 85  Novelty Detection                  Generalized Additive Models (GAM)
# 86  Novelty Detection                                   Nearest Neighbor
# 87    Motif Detection                            Maximum Likelihood (ML)
# 88   Visual Analytics                                   Pattern Analysis
# 89         Clustering                                Multiple Techniques
# 90  Novelty Detection           Classification and Regression Tree(CART)
# 91    Rule Extraction                      Support Vector Machines (SVM)
# 92   Visual Analytics                                Multiple Techniques
# 93   Visual Analytics                                   Pattern Analysis
# 94   Visual Analytics                                   Pattern Analysis
#
#          AppTagSpecific                                              title  \
# 0        Whole Building  Strip, bind, and search: a method for identify...
# 1              Controls  Sustainable Operation and Management of Data C...
# 2        Whole Building  Exploiting Generalized Additive Models for Dia...
# 3              Controls  Towards Automatic Spatial Verification of Sens...
# 4      Characterization  The energy dashboard: improving the visibility...
# 5             Targeting  Towards an understanding of campus-scale power...
# 6       Customer Class.  Reducing energy consumption by using self-orga...
# 7             Component  Sensor-fault detection, diagnosis and estimati...
# 8             Targeting  Using principal component and cluster analysis...
# 9       Customer Class.  Classification of Commerical Building Electric...
# 10       Whole Building  A framework for knowledge discovery in massive...
# 11     Characterization  Automated daily pattern filtering of measured ...
# 12  Occupancy Detection  A context-aware method for building occupancy ...
# 13            Subsystem  A model-based fault detection and diagnostic m...
# 14            Component  A novel methodology for knowledge discovery th...
# 15            Subsystem  A system-level fault detection and diagnosis s...
# 16            Targeting  Assessment of potential energy saving using cl...
# 17          Classifying  Cluster analysis of simulated energy use for L...
# 18            Targeting  Data association mining for identifying lighti...
# 19    Energy Management  Data mining in building automation system for ...
# 20            Component  Fault diagnosis for sensors in air handling un...
# 21          Classifying                                                NaN
# 22  Occupancy Detection  Occupancy schedules learning process through a...
# 23     Characterization  Pattern recognition algorithm for determining ...
# 24     Characterization  Principal component analysis of electricity us...
# 25    Energy Management  Temporal Knowledge Discovery in Big BAS Data f...
# 26          Classifying  Using intelligent clustering techniques to cla...
# 27       Whole Building  Using intelligent data analysis to detect abno...
# 28     Characterization  Visualizing building energy demand for buildin...
# 29     Characterization  Building energy information systems: user case...
# ..                  ...                                                ...
# 65             Controls  Prediction of Chiller Power Consumption Using ...
# 66       Whole Building  Real-time detection of anomalous power consump...
# 67    Energy Management                                                NaN
# 68     Characterization                                                NaN
# 69      Customer Class.                                                NaN
# 70     Characterization                                                NaN
# 71       Load Profiling  Low-voltage electricity customer profiling bas...
# 72      Customer Class.  A novelty detection approach to identify the o...
# 73       Load Profiling  Improving load forecast accuracy by clustering...
# 74       Load Profiling       SmartD: Smart Meter Data Analytics Dashboard
# 75            Subsystem  Wakame: Sense Making of Multi-dimensional Spat...
# 76       Disaggregation  A Temporal Motif Mining Approach to Unsupervis...
# 77  Occupancy Detection  Sensor mining for user behavior profiling in i...
# 78             Controls  Data Mining for Modeling Chiller Systems in Da...
# 79       Whole Building  Anomaly detection for visual analytics of powe...
# 80            Targeting  Improving energy efficiency in buildings using...
# 81  Occupancy Detection  A Learning Approach for Energy Efficiency Opti...
# 82     Characterization  Analysis of electricity bills using visual con...
# 83             Controls  Finding the Different Patterns in Buildings Da...
# 84       Load Profiling  Feature-based clustering for electricity use t...
# 85       Whole Building  Statistical Anomaly Detection in Mean and Vari...
# 86            Subsystem  Computational intelligence based anomaly detec...
# 87  Occupancy Detection  Softgreen: Towards energy management of green ...
# 88    Energy Management  Energy Consumption Improvement Through a Visua...
# 89       Load Profiling  Evaluation of the performance of clustering al...
# 90       Whole Building  A method for detecting abnormal electricity en...
# 91             Controls  Learning decision rules for energy efficient b...
# 92      Customer Class.  A new framework for the analysis of large scal...
# 93             Controls  Visualizing frequent patterns in large multiva...
# 94    Energy Management  Discovering unexpected information using a bui...
#
#                                   ID
# 0              fontugne\_strip\_2013
# 1         patnaik\_sustainable\_2009
# 2        ploennigs\_exploiting\_2013
# 3                hong\_towards\_2013
# 4              agarwal\_energy\_2009
# 5             bellala\_towards\_2011
# 6            rasanen\_reducing\_2008
# 7           wang\_sensor-fault\_2005
# 8               gaitani\_using\_2010
# 9      florita\_classification\_2012
# 10              fan\_framework\_2015
# 11           miller\_automated\_2015
# 12  adamopoulou\_context-aware\_2015
# 13             li\_model-based\_2014
# 14                   yu\_novel\_2012
# 15          wang\_system-level\_2010
# 16       petcharat\_assessment\_2012
# 17       heidarinejad\_cluster\_2014
# 18               cabrera\_data\_2013
# 19                  xiao\_data\_2014
# 20                  zhu\_fault\_2012
# 21                               NaN
# 22             doca\_occupancy\_2015
# 23               seem\_pattern\_2005
# 24              lam\_principal\_2008
# 25               fan\_temporal\_2015
# 26          santamouris\_using\_2007
# 27                 seem\_using\_2006
# 28      yarbrough\_visualizing\_2015
# 29        granderson\_building\_2010
# ..                               ...
# 65             fan\_prediction\_2013
# 66             chou\_real-time\_2014
# 67                               NaN
# 68                               NaN
# 69                               NaN
# 70                               NaN
# 71          gullo\_low-voltage\_2009
# 72            fagiani\_novelty\_2015
# 73        shahzadeh\_improving\_2015
# 74     jarrah\_nezhad\_smartd:\_2014
# 75           forlines\_wakame:\_2010
# 76              shao\_temporal\_2013
# 77             augello\_sensor\_2011
# 78               patnaik\_data\_2010
# 79           janetzko\_anomaly\_2013
# 80           sedano\_improving\_2009
# 81            mansur\_learning\_2015
# 82             moran\_analysis\_2013
# 83              habib\_finding\_2015
# 84      rasanen\_feature-based\_2009
# 85           chen\_statistical\_2014
# 86        linda\_computational\_2012
# 87   thanayankizil\_softgreen:\_2012
# 88               lange\_energy\_2012
# 89     panapakidis\_evaluation\_2015
# 90                 liu\_method\_2010
# 91          domahidi\_learning\_2014
# 92                 cakmak\_new\_2014
# 93            hao\_visualizing\_2011
# 94          lange\_discovering\_2013
#
# [95 rows x 15 columns]

# %%
fig = plt.figure()

stackedbars = mergeddata_labelled.groupby(['PublicationType','Sector']).count()
to_plot = stackedbars.unstack()['Title']
ax = to_plot.ix[to_plot.sum(axis=1).order().index].plot(kind='barh',stacked=True, figsize=(4,4), title="Publication Venue Breakdown", colormap = "viridis")
ax.set_xlabel("Number of Publications")

plt.savefig("PublicationVenues.pdf",bbox_inches='tight');
# Out:
# /Users/Clayton/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: order is deprecated, use sort_values(...)
